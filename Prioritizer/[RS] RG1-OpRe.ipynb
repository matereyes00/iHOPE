# %% [markdown]
# The goal of this phase of the study is to obtain locations maximizing the population in the selected areas.
#
# For instance, areas with a population under 20000 will not be considered optimal because there is no population to be covered by an RHU.

# %% [markdown]
# # Install libraries, tools, etc.

# %%
# !pip install ortools
# !pip install tensorflow
# !pip install imbalanced-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.3/309.3 kB 2.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires protobuf<5,>=3.20, but you have protobuf 5.27.2 which is incompatible.
# ...

# %% [markdown]
# candidate sites: [2866789,
#  2866797,
#  2866798,
#  2866799,
#  2868169,
#  2868170,
#  2868172,
#  2868179,
#  2868180,
#  2869548,
#  2869554,
#  2869558,
#  2869562,
#  2869563,
#  2869564,
#  2869565,
#  2869570,
#  2870928,
#  2870934,
#  2870935,
#  2870936,
#  2870941,
#  2870944,
#  2870945,
#  2870946,
#  2872309,
#  2872310,
#  2872318,
#  2872319,
#  2872320,
#  2872324,
#  2872326,
#  2872327,
#  2872328,
#  2872329,
#  2873690,
#  2873691,
#  2873697,
#  2873702,
#  2873703,
#  2873708,
#  2873709,
#  2873710,
#  2873711,
#  2875073,
#  2875076,
#  2875079,
#  2875080,
#  2875088,
#  2875089,
#  2875090,
#  2875091,
#  2875092,
#  2876455,
#  2876458,
#  2876459,
#  2876460,
#  2876461,
#  2876462,
#  2876467,
#  2876468,
#  2876471,
#  2876473,
#  2876474,
#  2876475,
#  2877836,
#  2877837,
#  2877841,
#  2877860,
#  2879218,
#  2879224,
#  2879225,
#  2879228,
#  2879241,
#  2879244,
#  2880607,
#  2880612,
#  2880616,
#  2880619,
#  2880620,
#  2880621,
#  2880625,
#  2880626,
#  2880627,
#  2880628,
#  2880629,
#  2881987,
#  2881995,
#  2881996,
#  2882000,
#  2882001,
#  2882002,
#  2882003,
#  2882007,
#  2882008,
#  2882009,
#  2882010,
#  2882011,
#  2883365,
#  2883377,
#  2883378,
#  2883379,
#  2883381,
#  2883382,
#  2883383,
#  2883384,
#  2883385,
#  2883386,
#  2883387,
#  2883391,
#  2883392,
#  2883393,
#  2883394,
#  2884758,
#  2884759,
#  2884760,
#  2884761,
#  2884764,
#  2884765,
#  2884766,
#  2884767,
#  2884768,
#  2884769,
#  2884770,
#  2884772,
#  2884773,
#  2884774,
#  2884775,
#  2886140,
#  2886143,
#  2886144,
#  2886146,
#  2886147,
#  2886148,
#  2886149,
#  2886150,
#  2886151,
#  2886152,
#  2886153,
#  2886154,
#  2886155,
#  2886156,
#  2886157,
#  2886161,
#  2887527,
#  2887528,
#  2887529,
#  2887530,
#  2887531,
#  2887532,
#  2887533,
#  2887534,
#  2887535,
#  2887536,
#  2887537,
#  2887538,
#  2887544,
#  2887545,
#  2888904,
#  2888910,
#  2888911,
#  2888912,
#  2888913,
#  2888914,
#  2888915,
#  2888916,
#  2888917,
#  2888918,
#  2888919,
#  2888920,
#  2888927,
#  2890293,
#  2890294,
#  2890295,
#  2890296,
#  2890297,
#  2890298,
#  2890299,
#  2890300,
#  2890301,
#  2890308,
#  2891674,
#  2891675,
#  2891676,
#  2891677,
#  2891678,
#  2891679,
#  2891680,
#  2891681,
#  2891682,
#  2891683,
#  2891690,
#  2891691,
#  2893056,
#  2893057,
#  2893058,
#  2893059,
#  2893060,
#  2893061,
#  2893062,
#  2893063,
#  2893064,
#  2894440,
#  2894441,
#  2894442,
#  2894443,
#  2894444,
#  2894445,
#  2894446,
#  2894447,
#  2895816,
#  2895822,
#  2895823,
#  2895824,
#  2895825,
#  2895826,
#  2895827,
#  2895828,
#  2897199,
#  2897204,
#  2897205,
#  2897206,
#  2897207,
#  2897208,
#  2897209,
#  2897210,
#  2897211,
#  2898585,
#  2898586,
#  2898587,
#  2898588,
#  2898589,
#  2898590,
#  2898591,
#  2898592,
#  2898593,
#  2899968,
#  2899969,
#  2899970,
#  2899974,
#  2899975,
#  2901345,
#  2901346,
#  2901350,
#  2901351,
#  2901356,
#  2901357,
#  2902726,
#  2902732,
#  2902733,
#  2902737,
#  2902738,
#  2902739,
#  2902740,
#  2902741,
#  2904111,
#  2904118,
#  2904119,
#  2904120,
#  2904121,
#  2904122,
#  2904123,
#  2904126,
#  2904127,
#  2905500,
#  2905501,
#  2905502,
#  2905503,
#  2905504,
#  2905505,
#  2905508,
#  2905509,
#  2905510,
#  2906881,
#  2906882,
#  2906883,
#  2906884,
#  2906885,
#  2906886,
#  2906889,
#  2906890,
#  2906891,
#  2906892,
#  2906893,
#  2906894,
#  2908264,
#  2908265,
#  2908266,
#  2908267,
#  2908268,
#  2908269,
#  2908271,
#  2908272,
#  2908273,
#  2908274,
#  2908275,
#  2908276,
#  2909647,
#  2909648,
#  2909649,
#  2909650,
#  2909652,
#  2909653,
#  2909654,
#  2909656,
#  2909657,
#  2911030,
#  2911031,
#  2911032,
#  2911033,
#  2911034,
#  2911035,
#  2911036,
#  2911037,
#  2911038,
#  2911039,
#  2912413,
#  2912415,
#  2912416,
#  2912417,
#  2912418,
#  2912419,
#  2912420,
#  2912423,
#  2913796,
#  2913797,
#  2913798,
#  2913799,
#  2913800,
#  2913801,
#  2913802,
#  2913805,
#  2915170,
#  2915181,
#  2915182,
#  2915183,
#  2915186,
#  2916564,
#  2916565,
#  2916568,
#  2917950,
#  2920714,
#  2922092,
#  2922094,
#  2923475,
#  2923476,
#  2924806,
#  2924856,
#  2924857,
#  2924858,
#  2924866,
#  2926187,
#  2926188,
#  2926190,
#  2926192,
#  2926225,
#  2926226,
#  2926238,
#  2927568,
#  2927569,
#  2927573,
#  2927574,
#  2927578,
#  2927590,
#  2927592,
#  2927607,
#  2927608,
#  2927620,
#  2928883,
#  2928949,
#  2928952,
#  2928953,
#  2928954,
#  2928956,
#  2928972,
#  2928973,
#  2928999,
#  2929001,
#  2930262,
#  2930331,
#  2930332,
#  2930335,
#  2930336,
#  2930337,
#  2930338,
#  2930339,
#  2930383,
#  2930384,
#  2931704,
#  2931712,
#  2931717,
#  2931718,
#  2931720,
#  2931721,
#  2931763,
#  2931765,
#  2931766,
#  2933091,
#  2933095,
#  2933096,
#  2933097,
#  2933098,
#  2933099,
#  2933100,
#  2933147,
#  2933149,
#  2934419,
#  2934458,
#  2934475,
#  2934476,
#  2934477,
#  2934478,
#  2934479,
#  2934480,
#  2934496,
#  2934504,
#  2934528,
#  2934531,
#  2935818,
#  2935840,
#  2935841,
#  2935851,
#  2935852,
#  2935860,
#  2935861,
#  2935862,
#  2935877,
#  2935912,
#  2935913,
#  2937185,
#  2937194,
#  2937226,
#  2937227,
#  2937232,
#  2937264,
#  2937265,
#  2938557,
#  2938608,
#  2938609,
#  2938610,
#  2938611,
#  2938655,
#  2939938,
#  2939941,
#  2939942,
#  2939990,
#  2939991,
#  2939992,
#  2940042,
#  2940058,
#  2941310,
#  2941314,
#  2941315,
#  2941316,
#  2941322,
#  2941323,
#  2941324,
#  2941325,
#  2941372,
#  2941373,
#  2941406,
#  2941412,
#  2941424,
#  2941426,
#  2941442,
#  2942691,
#  2942692,
#  2942694,
#  2942697,
#  2942698,
#  2942703,
#  2942704,
#  2942705,
#  2942706,
#  2942707,
#  2942753,
#  2942762,
#  2942807,
#  2942823,
#  2942825,
#  2944074,
#  2944075,
#  2944080,
#  2944081,
#  2944082,
#  2944083,
#  2944085,
#  2944086,
#  2944087,
#  2944136,
#  2944191,
#  2944203,
#  2944211,
#  2945440,
#  2945451,
#  2945456,
#  2945457,
#  2945458,
#  2945461,
#  2945462,
#  2945463,
#  2945464,
#  2945466,
#  2945475,
#  2945583,
#  2945593,
#  2946833,
#  2946839,
#  2946840,
#  2946841,
#  2946844,
#  2946845,
#  2946846,
#  2946847,
#  2946858,
#  2946965,
#  2946966,
#  2948210,
#  2948211,
#  2948221,
#  2948222,
#  2948223,
#  2948226,
#  2948240,
#  2948245,
#  2948246,
#  2948250,
#  2948328,
#  2948345,
#  2948346,
#  2949593,
#  2949598,
#  2949599,
#  2949600,
#  2949601,
#  2949602,
#  2949603,
#  2949604,
#  2949605,
#  2949622,
#  2949623,
#  2949627,
#  2949628,
#  2949634,
#  2949647,
#  2950978,
#  2950979,
#  2950980,
#  2950981,
#  2950982,
#  2950983,
#  2950984,
#  2950985,
#  2951003,
#  2951004,
#  2951008,
#  2951009,
#  2951010,
#  2952360,
#  2952361,
#  2952362,
#  2952363,
#  2952364,
#  2952365,
#  2952366,
#  2952386,
#  2952387,
#  2952388,
#  2952389,
#  2952390,
#  2952391,
#  2953742,
#  2953743,
#  2953744,
#  2953745,
#  2953746,
#  2953747,
#  2953768,
#  2955118,
#  2955119,
#  2955127,
#  2955244,
#  2956479,
#  2956481,
#  2956491,
#  2956495,
#  2956496,
#  2956497,
#  2956498,
#  2956499,
#  2956626,
#  2957879,
#  2957881,
#  2958023,
#  2959239,
#  2959262,
#  2959387,
#  2959388,
#  2960622,
#  2960623,
#  2960710,
#  2960769,
#  2960770,
#  2960771,
#  2962005,
#  2962006,
#  2962007,
#  2962013,
#  2962022,
#  2962023,
#  2962083,
#  2962084,
#  2962151,
#  2962152,
#  2963388,
#  2963401,
#  2963403,
#  2963404,
#  2963414,
#  2963415,
#  2963474,
#  2963475,
#  2963533,
#  2963534,
#  2963550,
#  2963554,
#  2964796,
#  2964857,
#  2964858,
#  2964859,
#  2964932,
#  2966176,
#  2966240,
#  2966241,
#  2966315,
#  2967558,
#  2967622,
#  2967623,
#  2967681,
#  2968940,
#  2968941,
#  2969064,
#  2970295,
#  2970319,
#  2970320,
#  2970321,
#  2970322,
#  2970323,
#  2971701,
#  2971702,
#  2971703,
#  2971704,
#  2971705,
#  2971706,
#  2971845,
#  2971846,
#  2973082,
#  2973083,
#  2973084,
#  2973085,
#  2973086,
#  2973087,
#  2973088,
#  2973223,
#  2973225,
#  2973226,
#  2973227,
#  2973228,
#  2974463,
#  2974464,
#  2974465,
#  2974466,
#  2974467,
#  2974468,
#  2974469,
#  2974470,
#  2974605,
#  2974606,
#  2974607,
#  2974608,
#  2974609,
#  2974610,
#  2975843,
#  2975844,
#  2975845,
#  2975846,
#  2975847,
#  2975848,
#  2975849,
#  2975850,
#  2975851,
#  2975988,
#  2975989,
#  2975990,
#  2975991,
#  2975993,
#  2975994,
#  2977192,
#  2977220,
#  2977226,
#  2977227,
#  2977228,
#  2977229,
#  2977230,
#  2977231,
#  2977232,
#  2977370,
#  2977371,
#  2977372,
#  2977375,
#  2977376,
#  2978601,
#  2978603,
#  2978608,
#  2978609,
#  2978610,
#  2978611,
#  2978612,
#  2978613,
#  2978755,
#  2978756,
#  2979985,
#  2979991,
#  2979992,
#  2979993,
#  2979994,
#  2979995,
#  2980135,
#  2981365,
#  2981366,
#  2981371,
#  2981373,
#  2981374,
#  2981375,
#  2981376,
#  2981377,
#  2981515,
#  2981516,
#  2982747,
#  2982748,
#  2982749,
#  2982751,
#  2982756,
#  2982757,
#  2982758,
#  2982759,
#  2982898,
#  2984127,
#  2984128,
#  2984129,
#  2984130,
#  2984133,
#  2984134,
#  2984138,
#  2984139,
#  2984140,
#  2984141,
#  2985509,
#  2985510,
#  2985511,
#  2985512,
#  2985513,
#  2985515,
#  2985516,
#  2985517,
#  2985518,
#  2985520,
#  2985521,
#  2985522,
#  2985523,
#  2985524,
#  2985660,
#  2986890,
#  2986891,
#  2986892,
#  2986893,
#  2986894,
#  2986895,
#  2986897,
#  2986898,
#  2986899,
#  2986901,
#  2986903,
#  2986904,
#  2986905,
#  2988272,
#  2988273,
#  2988274,
#  2988275,
#  2988276,
#  2988277,
#  2988278,
#  2988280,
#  2988281,
#  2988282,
#  2988285,
#  2988286,
#  2988287,
#  2989653,
#  2989654,
#  2989655,
#  2989656,
#  2989657,
#  2989658,
#  2989666,
#  2989667,
#  2991035,
#  2991036,
#  2991037,
#  2991038,
#  2991039,
#  2992418]

# %% [markdown]
# optimal sites: [2888904, 2879241, 2886146, 2934504, 2880629, 2924806, 2877860, 2926188, 2927569, 2926187, 2926192, 2926190, 2886161, 2963475, 2964859, 2966240, 2967622, 2966241, 2962084, 2962083, 2944191, 2927590, 2946965, 2948346, 2946966, 2931721, 2941372, 2948345, 2934475, 2969064, 2915170, 2938611, 2869558, 2967681, 2931720, 2915186, 2912423, 2913805, 2916568, 2944136, 2942762, 2888927, 2891691, 2891690, 2890308, 2945463, 2945464, 2946846, 2944082, 2944083, 2946847, 2905500, 2906881, 2902737, 2904118, 2899974, 2887545, 2956481, 2887544, 2934476, 2883394, 2882011, 2948211, 2946845, 2946844, 2948226, 2944081, 2945462, 2945461, 2942698, 2944080, 2942697, 2927608, 2901356, 2880628, 2880627, 2879244, 2924866, 2926225, 2937185, 2886155, 2882008, 2887536, 2883391, 2884772, 2882009, 2888919, 2909647, 2908265, 2908264, 2888920, 2890301, 2884775, 2886156, 2886157, 2887537, 2887538, 2883393, 2883392, 2884774, 2890300, 2884773, 2891683, 2882010, 2960769, 2962152, 2963534, 2886140, 2963533, 2959388, 2960770, 2875076, 2962151, 2960771, 2959387, 2985660, 2926226, 2949623, 2941316, 2945458, 2948223, 2946841, 2927574, 2937194, 2912413, 2911033, 2913796, 2902733, 2898587, 2901351, 2898589, 2895823, 2898588, 2899970, 2897206, 2946833, 2949599, 2949598, 2950979, 2950978, 2942753, 2917950, 2980135, 2978755, 2930262, 2901357, 2904121, 2904119, 2904120, 2905501, 2905502, 2902740, 2905503, 2906883, 2902739, 2906882, 2909648, 2902738, 2906884, 2906885, 2908266, 2941314, 2981515, 2949647, 2920714, 2909650, 2908267, 2908269, 2911030, 2911031, 2908268, 2911032, 2909649, 2905505, 2905504, 2904123, 2904122, 2906886, 2902741, 2941315, 2941406, 2928883, 2884765, 2886147, 2884764, 2941424, 2940042, 2938557, 2952388, 2952386, 2953768, 2939938, 2879218, 2908274, 2912417, 2911034, 2909654, 2911035, 2911036, 2911037, 2909653, 2912416, 2906891, 2915181, 2912418, 2906892, 2908273, 2913799, 2913800, 2908272, 2905510, 2898585, 2895822, 2897205, 2897204, 2898586, 2897199, 2895816, 2876471, 2956479, 2939990, 2937226, 2938608, 2904111, 2901346, 2901345, 2930332, 2948222, 2949604, 2945457, 2950985, 2946839, 2946840, 2945456, 2949605, 2949603, 2948221, 2942694, 2930335, 2931718, 2930336, 2931717, 2930337, 2928953, 2934458, 2935840, 2935841, 2873690, 2949634, 2982898, 2981516, 2868179, 2866797, 2877837, 2928949, 2905509, 2904127, 2906890, 2904126, 2905508, 2906889, 2909652, 2908271, 2939992, 2951008, 2952389, 2941324, 2952391, 2952390, 2951009, 2939941, 2872310, 2873691, 2876455, 2872309, 2870928, 2875073, 2906893, 2962023, 2883365, 2938609, 2882007, 2880626, 2935852, 2937232, 2935851, 2935818, 2913798, 2912415, 2913797, 2948240, 2945475, 2946858, 2913801, 2911039, 2912419, 2909657, 2909656, 2912420, 2906894, 2913802, 2908276, 2908275, 2915182, 2915183, 2916564, 2916565, 2911038, 2937227, 2931704, 2941412, 2964796, 2928972, 2928973, 2886154, 2886152, 2888916, 2888915, 2888914, 2888913, 2887535, 2890298, 2890299, 2887534, 2887533, 2887532, 2887531, 2886153, 2888917, 2884770, 2888918, 2886151, 2886150, 2884768, 2884769, 2869548, 2962022, 2963403, 2949593, 2948210, 2927573, 2877836, 2938655, 2948328, 2927592, 2869570, 2876458, 2877841, 2952387, 2951003, 2949622, 2951004, 2868169, 2890295, 2890293, 2894441, 2894443, 2894445, 2894446, 2890294, 2895824, 2895825, 2895826]

# %%
from ortools.linear_solver import pywraplp
import pandas as pd
from google.colab import drive
import numpy as np
from ortools.linear_solver import pywraplp
from ortools.sat.python import cp_model
from ortools.linear_solver import pywraplp
import joblib
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

drive.mount('/content/drive')
data_dir = "/content/drive/MyDrive/MS thesis"
# Out:
# Mounted at /content/drive

# %%
def process_population_density(rg1_clustered_df, os, a=1.65):
    # Filtering the DataFrame using the list of IDs
    os_df = rg1_clustered_df[rg1_clustered_df['ID'].isin(os)]

    # Population density columns
    all_pd = os_df['popden_all']
    women_pd = os_df['popden_wom']
    womenrep_pd = os_df['popden_w_1']
    youth_pd = os_df['popden_you']
    elder_pd = os_df['popden_eld']
    children_pd = os_df['popden_chi']

    # Calculating total population based on the multiplier 'a'
    os_df['total_population'] = all_pd * a
    os_df['total_population_women'] = women_pd * a
    os_df['total_population_womenrep'] = womenrep_pd * a
    os_df['total_population_youth'] = youth_pd * a
    os_df['total_population_elderly'] = elder_pd * a
    os_df['total_population_children'] = children_pd * a

    return os_df

def HCI_calc(total_ai, total_gi, total_hi, total_ji, total_ki, total_mi,distance, road_bi, POI_ci, landCov_di, hazard1_ei, hazard2_ei, hazard3_ei, rhus_fi):
    total_vulnerable = total_gi + total_hi + total_ji + total_ki + total_mi
    total_pop = total_ai
    population_to_be_served = total_vulnerable + np.maximum(0, total_pop - total_vulnerable)
    # Calculate y for the entire Series without using if condition
    y = np.where(population_to_be_served == 0, 0, 20000 / ((population_to_be_served) * (distance + rhus_fi)))
    mc = np.tanh(y)
    w_bi = 0.3 # roads
    w_ci = 0.2 # POIs
    w_di = 0.5 # land cov
    b = (POI_ci * w_ci) + (road_bi * w_bi) + (landCov_di * w_di)
    # Normalize each factor
    rain_intensity_normalized = (hazard1_ei - hazard1_ei.min()) / (hazard1_ei.max() - hazard1_ei.min())
    flood_probability_normalized = (hazard2_ei - hazard2_ei.min()) / (hazard2_ei.max() - hazard2_ei.min())
    drought_mean_normalized = (hazard3_ei - hazard3_ei.min()) / (hazard3_ei.max() - hazard3_ei.min())
    w_rain = 0.4
    w_flood = 0.3
    w_drought = 0.3
    c = (w_rain * rain_intensity_normalized) + (w_flood * flood_probability_normalized) + (w_drought * drought_mean_normalized)
    f = b - c
    f = np.tanh(f)
    hci = mc * f
    hcfai = (1 + np.tanh(hci / 2)) / 2  # Sigmoid function
    return hcfai

  # Define weights for each population group

weights = {
    'popden_wom': 2,
    'popden_chi': 2,
    'popden_w_1': 2,
    'popden_you': 1,
    'popden_eld': 1
}

# Define and train the models

# %% [markdown]
# # Region 1

# %% [markdown]
# ## Get optimal sites + EDA

# %%
# os = [2888904, 2879241, 2886146, 2934504, 2880629, 2924806, 2877860, 2926188, 2927569, 2926187, 2926192, 2926190, 2886161, 2963475, 2964859, 2966240, 2967622, 2966241, 2962084, 2962083, 2944191, 2927590, 2946965, 2948346, 2946966, 2931721, 2941372, 2948345, 2934475, 2969064, 2915170, 2938611, 2869558, 2967681, 2931720, 2915186, 2912423, 2913805, 2916568, 2944136, 2942762, 2888927, 2891691, 2891690, 2890308, 2945463, 2945464, 2946846, 2944082, 2944083, 2946847, 2905500, 2906881, 2902737, 2904118, 2899974, 2887545, 2956481, 2887544, 2934476, 2883394, 2882011, 2948211, 2946845, 2946844, 2948226, 2944081, 2945462, 2945461, 2942698, 2944080, 2942697, 2927608, 2901356, 2880628, 2880627, 2879244, 2924866, 2926225, 2937185, 2886155, 2882008, 2887536, 2883391, 2884772, 2882009, 2888919, 2909647, 2908265, 2908264, 2888920, 2890301, 2884775, 2886156, 2886157, 2887537, 2887538, 2883393, 2883392, 2884774, 2890300, 2884773, 2891683, 2882010, 2960769, 2962152, 2963534, 2886140, 2963533, 2959388, 2960770, 2875076, 2962151, 2960771, 2959387, 2985660, 2926226, 2949623, 2941316, 2945458, 2948223, 2946841, 2927574, 2937194, 2912413, 2911033, 2913796, 2902733, 2898587, 2901351, 2898589, 2895823, 2898588, 2899970, 2897206, 2946833, 2949599, 2949598, 2950979, 2950978, 2942753, 2917950, 2980135, 2978755, 2930262, 2901357, 2904121, 2904119, 2904120, 2905501, 2905502, 2902740, 2905503, 2906883, 2902739, 2906882, 2909648, 2902738, 2906884, 2906885, 2908266, 2941314, 2981515, 2949647, 2920714, 2909650, 2908267, 2908269, 2911030, 2911031, 2908268, 2911032, 2909649, 2905505, 2905504, 2904123, 2904122, 2906886, 2902741, 2941315, 2941406, 2928883, 2884765, 2886147, 2884764, 2941424, 2940042, 2938557, 2952388, 2952386, 2953768, 2939938, 2879218, 2908274, 2912417, 2911034, 2909654, 2911035, 2911036, 2911037, 2909653, 2912416, 2906891, 2915181, 2912418, 2906892, 2908273, 2913799, 2913800, 2908272, 2905510, 2898585, 2895822, 2897205, 2897204, 2898586, 2897199, 2895816, 2876471, 2956479, 2939990, 2937226, 2938608, 2904111, 2901346, 2901345, 2930332, 2948222, 2949604, 2945457, 2950985, 2946839, 2946840, 2945456, 2949605, 2949603, 2948221, 2942694, 2930335, 2931718, 2930336, 2931717, 2930337, 2928953, 2934458, 2935840, 2935841, 2873690, 2949634, 2982898, 2981516, 2868179, 2866797, 2877837, 2928949, 2905509, 2904127, 2906890, 2904126, 2905508, 2906889, 2909652, 2908271, 2939992, 2951008, 2952389, 2941324, 2952391, 2952390, 2951009, 2939941, 2872310, 2873691, 2876455, 2872309, 2870928, 2875073, 2906893, 2962023, 2883365, 2938609, 2882007, 2880626, 2935852, 2937232, 2935851, 2935818, 2913798, 2912415, 2913797, 2948240, 2945475, 2946858, 2913801, 2911039, 2912419, 2909657, 2909656, 2912420, 2906894, 2913802, 2908276, 2908275, 2915182, 2915183, 2916564, 2916565, 2911038, 2937227, 2931704, 2941412, 2964796, 2928972, 2928973, 2886154, 2886152, 2888916, 2888915, 2888914, 2888913, 2887535, 2890298, 2890299, 2887534, 2887533, 2887532, 2887531, 2886153, 2888917, 2884770, 2888918, 2886151, 2886150, 2884768, 2884769, 2869548, 2962022, 2963403, 2949593, 2948210, 2927573, 2877836, 2938655, 2948328, 2927592, 2869570, 2876458, 2877841, 2952387, 2951003, 2949622, 2951004, 2868169, 2890295, 2890293, 2894441, 2894443, 2894445, 2894446, 2890294, 2895824, 2895825, 2895826]
os = [2971664, 2959396, 2904108, 2904109, 2959408, 2975837, 2975839, 2967686, 2967694, 2971838, 2971839, 2971840, 2916559, 2928882, 2920706, 2920707, 2920708, 2920709, 2920710, 2924812, 2924814, 2933026, 2933028, 2928935, 2928938, 2933036, 2869553, 2924861, 2928958, 2928959, 2937159, 2937175, 2937176, 2873689, 2873692, 2933085, 2937180, 2873696, 2928995, 2933104, 2929009, 2929008, 2933107, 2933109, 2933112, 2941308, 2941309, 2941312, 2877834, 2941340, 2945437, 2937245, 2933151, 2933152, 2933153, 2933150, 2937252, 2937253, 2945446, 2937257, 2945449, 2941353, 2941359, 2937263, 2941364, 2941377, 2881988, 2881989, 2945478, 2945477, 2945484, 2945485, 2945486, 2945487, 2945495, 2945496, 2945502, 2941411, 2945515, 2953707, 2953709, 2886134, 2949626, 2941437, 2949629, 2941438, 2941439, 2941446, 2957844, 2890280, 2957871, 2890290, 2945590, 2945591, 2945592, 2961990, 2949726, 2962014, 2949730, 2894435, 2949732, 2949733, 2958021, 2902727, 2958026, 2962150, 2962162, 2962165, 2962166, 2974455, 2974456, 2974457, 2974460, 2966303, 2911029, 2970454, 2970456, 2974604, 2927504, 2927505, 2927506, 2919323, 2919324, 2919325, 2919327, 2923429, 2931645, 2927554, 2927555, 2927557, 2927566, 2927577, 2927580, 2927581, 2927583, 2927584, 2927586, 2935783, 2935784, 2935787, 2935788, 2935797, 2931701, 2872311, 2931703, 2935800, 2935817, 2927626, 2927627, 2935820, 2935823, 2935824, 2935825, 2931736, 2935845, 2935846, 2931751, 2935847, 2939949, 2931760, 2939955, 2939956, 2944053, 2931767, 2931768, 2931769, 2931770, 2935867, 2931772, 2931771, 2939967, 2935874, 2944066, 2935876, 2935881, 2939980, 2939981, 2935894, 2944095, 2880608, 2944096, 2948194, 2948195, 2944098, 2944101, 2940006, 2944100, 2944104, 2944105, 2940010, 2948203, 2944108, 2944106, 2935919, 2944112, 2944114, 2944117, 2944120, 2944121, 2944123, 2944125, 2940030, 2952319, 2940044, 2940047, 2884752, 2948241, 2940054, 2948247, 2948248, 2948249, 2948265, 2956462, 2888890, 2944188, 2944198, 2944201, 2944209, 2944210, 2944212, 2893044, 2948356, 2964754, 2952474, 2952475, 2964776, 2964777, 2964778, 2956637, 2968930, 2956644, 2960781, 2973071, 2973073, 2977219, 2977221, 2909645, 2969075, 2985491, 2973219, 2973220, 2973221, 2973222, 2917938, 2917939, 2917942, 2930263, 2930265, 2926173, 2926176, 2926178, 2922088, 2922090, 2926186, 2926191, 2926194, 2926202, 2934402, 2981518, 2930321, 2870930, 2934417, 2934418, 2926231, 2930341, 2870950, 2926247, 2870949, 2930345, 2938538, 2930346, 2930347, 2934438, 2934439, 2930351, 2938544, 2930354, 2930356, 2938556, 2934462, 2934463, 2934465, 2875077, 2930375, 2938574, 2930385, 2930387, 2930388, 2930390, 2942683, 2934493, 2934494, 2942687, 2938593, 2934497, 2942690, 2938596, 2938605, 2934511, 2934513, 2942714, 2942715, 2942718, 2946817, 2942722, 2942723, 2934532, 2934533, 2938627, 2942725, 2942726, 2934535, 2934536, 2934537, 2938634, 2938635, 2938636, 2938633, 2942734, 2942742, 2942743, 2938648, 2942744, 2938649, 2938658, 2938663, 2883371, 2946860, 2938669, 2946865, 2946866, 2946868, 2946872, 2946889, 2955081, 2887508, 2946902, 2955095, 2955096, 2887514, 2942811, 2887516, 2951005, 2955104, 2942818, 2942819, 2887524, 2942827, 2942828, 2951021, 2942830, 2891656, 2951053, 2891661, 2946974, 2951092, 2870951, 2963395, 2963396, 2951115, 2955250, 2967547, 2955262]
data_dir = "/content/drive/MyDrive/MS thesis"
rg = 1
x = f"{data_dir}/preliminary site selection/RG{rg}/rg1-clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df
# Out:
#       Unnamed: 0       ID          barangay_name  city_name province_name  \
# 0              0  2865422  Ilio-ilio (Iliw-iliw)     Burgos    Pangasinan
# 1              1  2866789             Macaboboni       Agno    Pangasinan
# 2              2  2866790             Macaboboni       Agno    Pangasinan
# 3              3  2866791             Macaboboni       Agno    Pangasinan
# 4              4  2866795                Aloleng       Agno    Pangasinan
# ...          ...      ...                    ...        ...           ...
# 5724        5724  2992394               Pasaleng   Pagudpud  Ilocos Norte
# 5725        5725  2992395               Pasaleng   Pagudpud  Ilocos Norte
# 5726        5726  2992396           Adams (Pob.)      Adams  Ilocos Norte
# 5727        5727  2992397           Adams (Pob.)      Adams  Ilocos Norte
# 5728        5728  2992418             Santo Nino  Nueva Era  Ilocos Norte
#
#       popden_chi  popden_eld  popden_wom  popden_you  popden_w_1  ...  \
# ...

# %%
# Filtering the DataFrame using the list of IDs
os_df = rg1_clustered_df[rg1_clustered_df['ID'].isin(os)]
# os_df.columns
os_df = os_df.drop(columns=['Unnamed: 0'])
os_df
os_df.columns

a = 1.65 # or 13042??
all_pd = os_df['popden_all']
women_pd = os_df['popden_wom']
womenrep_pd = os_df['popden_w_1']
youth_pd = os_df['popden_you']
elder_pd = os_df['popden_eld']
children_pd = os_df['popden_chi']

os_df['total_population'] = all_pd * a
os_df['total_population_women'] = women_pd * a
os_df['total_population_womenrep'] = womenrep_pd * a
os_df['total_population_youth'] = youth_pd * a
os_df['total_population_elderly'] = elder_pd * a
os_df['total_population_children'] = children_pd * a

print(f"all: {os_df['total_population'].sum()}")
print(f"women: {os_df['total_population_women'].sum()}")
print(f"women reproductive : {os_df['total_population_womenrep'].sum()}")
print(f"youth: {os_df['total_population_youth'].sum()}")
print(f"elderly: {os_df['total_population_elderly'].sum()}")
print(f"children: {os_df['total_population_children'].sum()}")

os_df[os_df['total_population'] >= 20000]

import numpy as np
def HCI_calc(total_ai, total_gi, total_hi, total_ji, total_ki, total_mi,distance, road_bi, POI_ci, landCov_di, hazard1_ei, hazard2_ei, hazard3_ei, rhus_fi):
    total_vulnerable = total_gi + total_hi + total_ji + total_ki + total_mi
    total_pop = total_ai
    population_to_be_served = total_vulnerable + np.maximum(0, total_pop - total_vulnerable)
    # Calculate y for the entire Series without using if condition
    y = np.where(population_to_be_served == 0, 0, 20000 / ((population_to_be_served) * (distance + rhus_fi)))
    mc = np.tanh(y)
    w_bi = 0.3 # roads
    w_ci = 0.2 # POIs
    w_di = 0.5 # land cov
    b = (POI_ci * w_ci) + (road_bi * w_bi) + (landCov_di * w_di)
    # Normalize each factor
    rain_intensity_normalized = (hazard1_ei - hazard1_ei.min()) / (hazard1_ei.max() - hazard1_ei.min())
    flood_probability_normalized = (hazard2_ei - hazard2_ei.min()) / (hazard2_ei.max() - hazard2_ei.min())
    drought_mean_normalized = (hazard3_ei - hazard3_ei.min()) / (hazard3_ei.max() - hazard3_ei.min())
    w_rain = 0.4
    w_flood = 0.3
    w_drought = 0.3
    c = (w_rain * rain_intensity_normalized) + (w_flood * flood_probability_normalized) + (w_drought * drought_mean_normalized)
    f = b - c
    f = np.tanh(f)
    hci = mc * f
    hcfai = (1 + np.tanh(hci / 2)) / 2  # Sigmoid function
    return hcfai

os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])


os_df[os_df['popden_wom'] > 0] # 240 rows
os_df[os_df['popden_w_1'] > 0] # 240 rows
os_df[os_df['popden_chi'] > 0] # 240 rows

# os_df[os_df['total_population_women'] > 0] # 123 rows
# os_df[os_df['total_population_children'] > 0] # 123 rows
os_df[os_df['total_population_womenrep'] >0 ] # 123 rows

os_df[os_df['total_population_womenrep'] > 0] # 123 rows
# Out:
# all: 679889.4634695221
# women: 336007.18629414745
# women reproductive : 168956.95613821317
# youth: 128281.16777823401
# elderly: 60533.207001658215
# children: 72554.44618985814
#            ID      barangay_name city_name province_name  popden_chi  \
# 51    2869553          San Simon      Bani    Pangasinan  103.338574
# 75    2870930        Centro Toma      Bani    Pangasinan   51.781496
# 94    2870949           Pogoruac    Burgos    Pangasinan   33.618753
# 95    2870950           Pogoruac    Burgos    Pangasinan    2.181284
# 96    2870951                Uli     Dasol    Pangasinan   73.598896
# ...       ...                ...       ...           ...         ...
# 5104  2975839            Nalasin   Solsona  Ilocos Norte   93.763333
# 5179  2977219  Barbaqueso (Pob.)    Carasi  Ilocos Norte   38.832124
# 5181  2977221         Maananteng   Solsona  Ilocos Norte   18.299491
# 5426  2981518           Baracbac   Umingan    Pangasinan    1.698063
# ...

# %% [markdown]
# ## Get total population for each city

# %%
print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)

# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))

# Now you can print or display the visual DataFrame
grouped_df_visual

total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
# Convert the resulting Series back into a DataFrame
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df

# Now you can print or display the DataFrame
# total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()

# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()

# Now you can print or display the DataFrame
total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped

# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()

# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
# Out:
# ['Bani' 'Burgos' 'Dasol' 'Bolinao' 'City of Alaminos' 'Anda' 'Sual'
#  'Bugallon' 'Aguilar' 'City of San Carlos' 'Bauang' 'Mangatarem' 'Luna'
#  'Bacnotan' 'City of San Fernando' 'Aringay' 'Santa Catalina'
#  'City of Vigan' 'Balaoan' 'San Juan' 'Caba' 'Santo Domingo' 'Agoo'
#  'Santo Tomas' 'Calasiao' 'Urbiztondo' 'Bayambang' 'Mangaldan' 'Malasiqui'
#  'Magsingal' 'Caoayan' 'Naguilian' 'San Juan (Lapog)' 'Santa'
#  'City of Candon' 'Tubao' 'San Fabian' 'Cabugao' 'Santiago' 'Santa Lucia'
#  'Sinait' 'San Ildefonso' 'Badoc' 'Santa Maria' 'Santa Cruz' 'Tagudin'
#  'Rosario' 'Manaoag' 'Bagulin' 'Mapandan' 'Santol' 'Narvacan' 'Bautista'
#  'Paoay' 'Banayoyo' 'Galimuyod' 'Pozorrubio' 'City of Urdaneta' 'Lidlidda'
#  'Sugpon' 'City of Laoag' 'City of Batac' 'Salcedo (Baugen)' 'Nagbukel'
#  'Villasis' 'Alcala' 'San Emilio' 'Sison' 'Pasuquin' 'Asingan' 'Rosales'
#  'Sarrat' 'Bangui' 'Piddig' 'San Manuel' 'Balungao' 'Dingras' 'Tayug'
#  'Umingan' 'San Quintin' 'Carasi' 'Solsona' 'Adams']
# ...

# %% [markdown]
# ## OR implementation: Maximal Coverage location problem
# - looks for places that fit the 20k capacity
# - ouput: 4 locations have over or exactly 20000 individuals that can be served by 1 rhu
# - does not look into how many RHUs need to be put up

# %%
# rhu_coverage = 20000
# pcp = 20000
# phn = 10000
# mw = 5000
# san = 20000
# # Create the solver with the SCIP backend
# solver = pywraplp.Solver.CreateSolver("SCIP")
# if not solver:
#     raise Exception("Solver not found!")

# # Define sets
# J = set(os_df['ID'])
# city_names = set(os_df['city_name'])

# # Define decision variables
# is_population_in_area_j_covered = {}

# # Binary variable to indicate if the population in area j is covered
# for j in J:
#     is_population_in_area_j_covered[j] = solver.BoolVar(f"is_population_at_location_{j}_covered")

# # Constraints
# for index, row in os_df.iterrows():
#     j = row['ID']
#     city = row['city_name']
#     population = row['total_population']
#     # Constraint to ensure coverage based on population threshold
#     if population >= rhu_coverage:
#         solver.Add(is_population_in_area_j_covered[j] == 1)
#     #elif population >= mw:
#     #    solver.Add(is_population_in_area_j_covered[j] == 1)
#     #elif population >= pcp:
#     #    solver.Add(is_population_in_area_j_covered[j] == 1)
#     #elif population >= phn:
#     #    solver.Add(is_population_in_area_j_covered[j] == 1)
#     #elif population >= san:
#     #    solver.Add(is_population_in_area_j_covered[j] == 1)
#     else:
#         solver.Add(is_population_in_area_j_covered[j] == 0)

# # Objective function: maximize the number of covered populations
# objective = solver.Objective()
# for j in J:
#     objective.SetCoefficient(is_population_in_area_j_covered[j], 1)
# objective.SetMaximization()

# # Solve the problem
# status = solver.Solve()
# if status == pywraplp.Solver.OPTIMAL:
#     print('Solution:')
#     covered_areas = []
#     for j in J:
#       if is_population_in_area_j_covered[j].solution_value() == 1:
#           covered_areas.append(j)
#           print(f"Location {j}: Covered = {is_population_in_area_j_covered[j].solution_value()}")
# else:
#     print('The problem does not have an optimal solution.')

# %%
# # Accessing these on the dataframe
# covered_locations = os_df[os_df['ID'].isin(covered_areas)]
# covered_locations

# covered_locations.columns
# pangasinan_df = os_df[os_df['province_name'] == 'Pangasinan']
# #pangasinan_df[pangasinan_df['city_name']]
# # Group by 'city_name' and sum the 'total_population'

# #grouped_df = pangasinan_df.groupby('city_name')['total_population'].sum().reset_index()

# covered_locations[['flood_probability_value', 'rain intensity_value', 'drought_value',
#        'buildability_landcov', 'RHU_Presence', 'Road_Presence', 'POI_Presence',
#        'Nearest_RHU', 'Distance_to_Nearest_RHU_km']]

# %% [markdown]
# ## OR: Maximal coverage location problem 2
# - number of RHUs to be placed per city BASED on the population PER CITY
# - instead of getting the overall population of the region, we will instead use the population PER city (since there's no municipality) to determine the NUMBER of RHUs to be put up.
# - output:
# > (City)City of Dagupan: Build 5 RHUs
# > (City)City of San Fernando: Build 2 RHUs
# > (City)Lingayen: Build 1 RHUs
# > Total RHUs built: 8.0

# %%
from ortools.linear_solver import pywraplp
from ortools.sat.python import cp_model
from ortools.linear_solver import pywraplp

# Define RHU capacity
rhu_capacity = 20000

# Dictionary to store solutions for each solver
all_solutions = {}

# List of solver names
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']

# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")

    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")

    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)
# Out:
# Solving with SAT solver...
# Optimal solution found with SAT!
# Aguilar: Build 1 RHUs
# Bauang: Build 1 RHUs
# Bayambang: Build 3 RHUs
# City of San Carlos: Build 1 RHUs
# Luna: Build 1 RHUs
# Malasiqui: Build 1 RHUs
# Manaoag: Build 1 RHUs
# Santa Maria: Build 1 RHUs
# Total RHUs built: 10
# Solving with SCIP solver...
# Optimal solution found with SCIP!
# Aguilar: Build 1 RHUs
# Bauang: Build 1 RHUs
# Bayambang: Build 3 RHUs
# City of San Carlos: Build 1 RHUs
# Luna: Build 1 RHUs
# Malasiqui: Build 1 RHUs
# Manaoag: Build 1 RHUs
# Santa Maria: Build 1 RHUs
# Total RHUs built: 10
# Solving with GLOP solver...
# Optimal solution found with GLOP!
# Aguilar: Build 1 RHUs
# Bauang: Build 1 RHUs
# Bayambang: Build 3 RHUs
# City of San Carlos: Build 1 RHUs
# Luna: Build 1 RHUs
# Malasiqui: Build 1 RHUs
# Manaoag: Build 1 RHUs
# Santa Maria: Build 1 RHUs
# Total RHUs built: 10
# Solving with CBC solver...
# Optimal solution found with CBC!
# Aguilar: Build 1 RHUs
# Bauang: Build 1 RHUs
# ...

# %% [markdown]
# ## Recommendation System
# Primary Care Facilities (PCFs) provide services specifically
# for women and children such as maternal and newborn care, immunization, family planning and other
# reproductive health services. They are designed to have a Birthing Facility and lactation station for its
# catchment population based on the manual of standards.

# %%
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Load datasets
mother_directory = f"/content/drive/MyDrive/MS thesis/[optimize] Training, Testing/RG{rg}/"
PCF_df = pd.read_csv(mother_directory + "PCF_data.csv")
x = f"{data_dir}/preliminary site selection/RG{rg}/rg1-clusters.csv"
rg1_clustered_df = pd.read_csv(x)

print(rg1_clustered_df.columns)
rg1_clustered_df
# Out:
# Index(['Unnamed: 0', 'ID', 'barangay_name', 'city_name', 'province_name',
#        'popden_chi', 'popden_eld', 'popden_wom', 'popden_you', 'popden_w_1',
#        'popden_all', 'flood_probability_value', 'rain intensity_value',
#        'drought_value', 'buildability_landcov', 'RHU_Presence',
#        'Road_Presence', 'POI_Presence', 'Nearest_RHU',
#        'Distance_to_Nearest_RHU_km', 'Neighbors', 'HCFAI', 'Cluster'],
#       dtype='object')
#       Unnamed: 0       ID          barangay_name  city_name province_name  \
# 0              0  2865422  Ilio-ilio (Iliw-iliw)     Burgos    Pangasinan
# 1              1  2866789             Macaboboni       Agno    Pangasinan
# 2              2  2866790             Macaboboni       Agno    Pangasinan
# 3              3  2866791             Macaboboni       Agno    Pangasinan
# 4              4  2866795                Aloleng       Agno    Pangasinan
# ...          ...      ...                    ...        ...           ...
# ...

# %%
# Find columns with NaN values
columns_with_nan = rg1_clustered_df.columns[rg1_clustered_df.isnull().any()]

print("Columns with NaN values:")
print(columns_with_nan)

df_dropped = rg1_clustered_df.dropna()
df_dropped
# Out:
# Columns with NaN values:
# Index(['rain intensity_value', 'buildability_landcov', 'HCFAI', 'Cluster'], dtype='object')
#       Unnamed: 0       ID          barangay_name  city_name province_name  \
# 0              0  2865422  Ilio-ilio (Iliw-iliw)     Burgos    Pangasinan
# 1              1  2866789             Macaboboni       Agno    Pangasinan
# 2              2  2866790             Macaboboni       Agno    Pangasinan
# 3              3  2866791             Macaboboni       Agno    Pangasinan
# 4              4  2866795                Aloleng       Agno    Pangasinan
# ...          ...      ...                    ...        ...           ...
# 5724        5724  2992394               Pasaleng   Pagudpud  Ilocos Norte
# 5725        5725  2992395               Pasaleng   Pagudpud  Ilocos Norte
# 5726        5726  2992396           Adams (Pob.)      Adams  Ilocos Norte
# 5727        5727  2992397           Adams (Pob.)      Adams  Ilocos Norte
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# Features and target
X = df_dropped[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld']]
y = df_dropped['Cluster']

# Train a Random Forest model
model = RandomForestClassifier()
model.fit(X, y)

# Feature importance
feature_importances = model.feature_importances_
print("Feature Importances:", feature_importances)
# Out:
# Feature Importances: [0.20209505 0.19325004 0.1955623  0.19473592 0.21435669]

# %%
# Define weights for each population group
# weights = {
#     'popden_wom': 0.19928181,
#     'popden_chi': 0.19074426,
#     'popden_w_1': 0.1988759,
#     'popden_you': 0.1980582,
#     'popden_eld': 0.21303983
# }


# Calculate priority score for each location
rg1_clustered_df['Priority_Score'] = 0
for group, weight in weights.items():
    rg1_clustered_df['Priority_Score'] += rg1_clustered_df[group] * weight

# Normalize features
scaler = MinMaxScaler()
X = scaler.fit_transform(rg1_clustered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])
y = rg1_clustered_df['Priority_Score']

# Save the scaler for later use
joblib.dump(scaler, 'scaler.pkl')

# Initialize lists to store results
mse_results = {'Decision_Tree': [], 'SVR': [], 'Random_Forest': [], 'KNN': [], 'Neural_Network': []}
r2_results = {'Decision_Tree': [], 'SVR': [], 'Random_Forest': [], 'KNN': [], 'Neural_Network': []}
mae_results = {'Decision_Tree': [], 'SVR': [], 'Random_Forest': [], 'KNN': [], 'Neural_Network': []}

rg1_clustered_df = rg1_clustered_df.sample(frac=1, random_state=np.random.randint(1000))
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

# Multiple train/test splits with different random seeds
for i in range(10):  # Repeat 5 times with different random states
    # Randomly shuffle the DataFrame rows
    random_state = np.random.randint(1000)  # Generate a random seed

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)

    # Add random noise to the input features
    X_train_noisy = X_train + np.random.normal(loc=0, scale=0.1, size=X_train.shape)
    X_test_noisy = X_test + np.random.normal(loc=0, scale=0.1, size=X_test.shape)

    # Perturb the target labels
    y_train_noisy = y_train + np.random.normal(loc=0, scale=0.1, size=y_train.shape)
    y_test_noisy = y_test + np.random.normal(loc=0, scale=0.1, size=y_test.shape)

    # Define and train the models
    models = {
        'Decision_Tree': DecisionTreeRegressor(random_state=random_state),
        'SVR': SVR(kernel='linear'),
        'Random_Forest': RandomForestRegressor(random_state=random_state, n_estimators=100),
        'KNN': KNeighborsRegressor(n_neighbors=5),
        'Neural_Network': MLPRegressor(hidden_layer_sizes=(100, 100), max_iter=500, random_state=random_state)
    }

    # Train models and collect predictions
    for name, model in models.items():
        model.fit(X_train_noisy, y_train_noisy)
        preds = model.predict(X_test_noisy)

        # Calculate metrics
        mse_results[name].append(mean_squared_error(y_test_noisy, preds))
        r2_results[name].append(r2_score(y_test_noisy, preds))
        mae_results[name].append(mean_absolute_error(y_test_noisy, preds))

# Average the results over the different random states
avg_mse = {name: np.mean(values) for name, values in mse_results.items()}
avg_r2 = {name: np.mean(values) for name, values in r2_results.items()}
avg_mae = {name: np.mean(values) for name, values in mae_results.items()}

# Plotting the results
plt.figure(figsize=(14, 7))

# Plot Mean Squared Error
plt.subplot(1, 3, 1)
plt.bar(avg_mse.keys(), avg_mse.values(), color=['blue', 'green', 'red', 'purple', 'orange'])
plt.title('Mean Squared Error of Models')
plt.ylabel('Mean Squared Error')
plt.ylim([0, max(avg_mse.values()) + 1])  # Adjust ylim for better visualization

# Plot R-squared
plt.subplot(1, 3, 2)
plt.bar(avg_r2.keys(), avg_r2.values(), color=['blue', 'green', 'red', 'purple', 'orange'])
plt.title('R-squared of Models')
plt.ylabel('R-squared')
plt.ylim([0, 1])  # R-squared ranges from 0 to 1

# Plot Mean Absolute Error
plt.subplot(1, 3, 3)
plt.bar(avg_mae.keys(), avg_mae.values(), color=['blue', 'green', 'red', 'purple', 'orange'])
plt.title('Mean Absolute Error of Models')
plt.ylabel('Mean Absolute Error')
plt.ylim([0, max(avg_mae.values()) + 1])  # Adjust ylim for better visualization

plt.tight_layout()
plt.show()

# Save the trained models
for name, model in models.items():
    joblib.dump(model, f'{name}_model.pkl')

# %%
print(avg_r2.keys())
print(avg_mae.values())
print(avg_mse.values())
print(avg_r2.values())
# Out:
# dict_keys(['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network'])
# dict_values([1514.7695298737967, 1766.762880665718, 1144.102917193679, 1159.8069929370083, 1053.184080868304])
# dict_values([5239247.422864297, 13089264.268124597, 2537546.8807613207, 2750663.423679058, 2196696.6517666252])
# dict_values([0.5493784292294325, -0.1145978741587311, 0.7821720250833368, 0.764169257732609, 0.811339516313951])

# %%
# Save and load the models and their predictions
model_files = {
    'Random_Forest': "Random_Forest_model.pkl",
    'Decision_Tree': "Decision_Tree_model.pkl",
    'SVR': "SVR_model.pkl",
    'KNN': "KNN_model.pkl",
    'Neural_Network': "Neural_Network_model.pkl"
}

for name, model in models.items():
    joblib.dump(model, model_files[name])
    print(f"{name} model saved to {model_files[name]}")
    loaded_model = joblib.load(model_files[name])
    print(f"{name} model loaded from {model_files[name]}")
    preds = loaded_model.predict(X)
    rg1_clustered_df.loc[:, f'Predicted_Score_{name.replace(" ", "_")}'] = preds

import pandas as pd
import joblib
from sklearn.preprocessing import MinMaxScaler

# Define weights for each population group
weights = {
    'popden_wom': 2,
    'popden_chi': 2,
    'popden_w_1': 2,
    'popden_you': 1,
    'popden_eld': 1
}

# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load('scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

# Print the predictions
print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])


# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

# Print recommended locations for each city by each model
all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# Decision_Tree model saved to Decision_Tree_model.pkl
# Decision_Tree model loaded from Decision_Tree_model.pkl
# SVR model saved to SVR_model.pkl
# SVR model loaded from SVR_model.pkl
# Random_Forest model saved to Random_Forest_model.pkl
# Random_Forest model loaded from Random_Forest_model.pkl
# KNN model saved to KNN_model.pkl
# KNN model loaded from KNN_model.pkl
# Neural_Network model saved to Neural_Network_model.pkl
# Neural_Network model loaded from Neural_Network_model.pkl
#            ID  Priority_Score  Decision_Tree_Prediction  SVR_Prediction  \
# 51    2869553     1620.934026                 37.840116      613.746006
# 75    2870930      807.976055               1383.143546      604.660764
# 94    2870949      704.861917                381.723691      603.858664
# 95    2870950       43.340412                832.047795      595.032572
# 96    2870951     1317.133524                 37.840116      610.663771
# ...

# %% [markdown]
# # Region 1 - fix

# %%
# os = [2888904, 2879241, 2886146, 2934504, 2880629, 2924806, 2877860, 2926188, 2927569, 2926187, 2926192, 2926190, 2886161, 2963475, 2964859, 2966240, 2967622, 2966241, 2962084, 2962083, 2944191, 2927590, 2946965, 2948346, 2946966, 2931721, 2941372, 2948345, 2934475, 2969064, 2915170, 2938611, 2869558, 2967681, 2931720, 2915186, 2912423, 2913805, 2916568, 2944136, 2942762, 2888927, 2891691, 2891690, 2890308, 2945463, 2945464, 2946846, 2944082, 2944083, 2946847, 2905500, 2906881, 2902737, 2904118, 2899974, 2887545, 2956481, 2887544, 2934476, 2883394, 2882011, 2948211, 2946845, 2946844, 2948226, 2944081, 2945462, 2945461, 2942698, 2944080, 2942697, 2927608, 2901356, 2880628, 2880627, 2879244, 2924866, 2926225, 2937185, 2886155, 2882008, 2887536, 2883391, 2884772, 2882009, 2888919, 2909647, 2908265, 2908264, 2888920, 2890301, 2884775, 2886156, 2886157, 2887537, 2887538, 2883393, 2883392, 2884774, 2890300, 2884773, 2891683, 2882010, 2960769, 2962152, 2963534, 2886140, 2963533, 2959388, 2960770, 2875076, 2962151, 2960771, 2959387, 2985660, 2926226, 2949623, 2941316, 2945458, 2948223, 2946841, 2927574, 2937194, 2912413, 2911033, 2913796, 2902733, 2898587, 2901351, 2898589, 2895823, 2898588, 2899970, 2897206, 2946833, 2949599, 2949598, 2950979, 2950978, 2942753, 2917950, 2980135, 2978755, 2930262, 2901357, 2904121, 2904119, 2904120, 2905501, 2905502, 2902740, 2905503, 2906883, 2902739, 2906882, 2909648, 2902738, 2906884, 2906885, 2908266, 2941314, 2981515, 2949647, 2920714, 2909650, 2908267, 2908269, 2911030, 2911031, 2908268, 2911032, 2909649, 2905505, 2905504, 2904123, 2904122, 2906886, 2902741, 2941315, 2941406, 2928883, 2884765, 2886147, 2884764, 2941424, 2940042, 2938557, 2952388, 2952386, 2953768, 2939938, 2879218, 2908274, 2912417, 2911034, 2909654, 2911035, 2911036, 2911037, 2909653, 2912416, 2906891, 2915181, 2912418, 2906892, 2908273, 2913799, 2913800, 2908272, 2905510, 2898585, 2895822, 2897205, 2897204, 2898586, 2897199, 2895816, 2876471, 2956479, 2939990, 2937226, 2938608, 2904111, 2901346, 2901345, 2930332, 2948222, 2949604, 2945457, 2950985, 2946839, 2946840, 2945456, 2949605, 2949603, 2948221, 2942694, 2930335, 2931718, 2930336, 2931717, 2930337, 2928953, 2934458, 2935840, 2935841, 2873690, 2949634, 2982898, 2981516, 2868179, 2866797, 2877837, 2928949, 2905509, 2904127, 2906890, 2904126, 2905508, 2906889, 2909652, 2908271, 2939992, 2951008, 2952389, 2941324, 2952391, 2952390, 2951009, 2939941, 2872310, 2873691, 2876455, 2872309, 2870928, 2875073, 2906893, 2962023, 2883365, 2938609, 2882007, 2880626, 2935852, 2937232, 2935851, 2935818, 2913798, 2912415, 2913797, 2948240, 2945475, 2946858, 2913801, 2911039, 2912419, 2909657, 2909656, 2912420, 2906894, 2913802, 2908276, 2908275, 2915182, 2915183, 2916564, 2916565, 2911038, 2937227, 2931704, 2941412, 2964796, 2928972, 2928973, 2886154, 2886152, 2888916, 2888915, 2888914, 2888913, 2887535, 2890298, 2890299, 2887534, 2887533, 2887532, 2887531, 2886153, 2888917, 2884770, 2888918, 2886151, 2886150, 2884768, 2884769, 2869548, 2962022, 2963403, 2949593, 2948210, 2927573, 2877836, 2938655, 2948328, 2927592, 2869570, 2876458, 2877841, 2952387, 2951003, 2949622, 2951004, 2868169, 2890295, 2890293, 2894441, 2894443, 2894445, 2894446, 2890294, 2895824, 2895825, 2895826]
os = [2888904, 2879241, 2886146, 2934504, 2880629, 2924806, 2877860, 2926188, 2927569, 2926187, 2926192, 2926190, 2886161, 2963475, 2964859, 2966240, 2967622, 2966241, 2962084, 2962083, 2944191, 2927590, 2946965, 2948346, 2946966, 2931721, 2941372, 2948345, 2934475, 2969064, 2915170, 2938611, 2869558, 2967681, 2931720, 2915186, 2912423, 2913805, 2916568, 2944136, 2942762, 2888927, 2891691, 2891690, 2890308, 2945463, 2945464, 2946846, 2944082, 2944083, 2946847, 2905500, 2906881, 2902737, 2904118, 2899974, 2887545, 2956481, 2887544, 2934476, 2883394, 2882011, 2948211, 2946845, 2946844, 2948226, 2944081, 2945462, 2945461, 2942698, 2944080, 2942697, 2927608, 2901356, 2880628, 2880627, 2879244, 2924866, 2926225, 2937185, 2886155, 2882008, 2887536, 2883391, 2884772, 2882009, 2888919, 2909647, 2908265, 2908264, 2888920, 2890301, 2884775, 2886156, 2886157, 2887537, 2887538, 2883393, 2883392, 2884774, 2890300, 2884773, 2891683, 2882010, 2960769, 2962152, 2963534, 2886140, 2963533, 2959388, 2960770, 2875076, 2962151, 2960771, 2959387, 2985660, 2926226, 2949623, 2941316, 2945458, 2948223, 2946841, 2927574, 2937194, 2912413, 2911033, 2913796, 2902733, 2898587, 2901351, 2898589, 2895823, 2898588, 2899970, 2897206, 2946833, 2949599, 2949598, 2950979, 2950978, 2942753, 2917950, 2980135, 2978755, 2930262, 2901357, 2904121, 2904119, 2904120, 2905501, 2905502, 2902740, 2905503, 2906883, 2902739, 2906882, 2909648, 2902738, 2906884, 2906885, 2908266, 2941314, 2981515, 2949647, 2920714, 2909650, 2908267, 2908269, 2911030, 2911031, 2908268, 2911032, 2909649, 2905505, 2905504, 2904123, 2904122, 2906886, 2902741, 2941315, 2941406, 2928883, 2884765, 2886147, 2884764, 2941424, 2940042, 2938557, 2952388, 2952386, 2953768, 2939938, 2879218, 2908274, 2912417, 2911034, 2909654, 2911035, 2911036, 2911037, 2909653, 2912416, 2906891, 2915181, 2912418, 2906892, 2908273, 2913799, 2913800, 2908272, 2905510, 2898585, 2895822, 2897205, 2897204, 2898586, 2897199, 2895816, 2876471, 2956479, 2939990, 2937226, 2938608, 2904111, 2901346, 2901345, 2930332, 2948222, 2949604, 2945457, 2950985, 2946839, 2946840, 2945456, 2949605, 2949603, 2948221, 2942694, 2930335, 2931718, 2930336, 2931717, 2930337, 2928953, 2934458, 2935840, 2935841, 2873690, 2949634, 2982898, 2981516, 2868179, 2866797, 2877837, 2928949, 2905509, 2904127, 2906890, 2904126, 2905508, 2906889, 2909652, 2908271, 2939992, 2951008, 2952389, 2941324, 2952391, 2952390, 2951009, 2939941, 2872310, 2873691, 2876455, 2872309, 2870928, 2875073, 2906893, 2962023, 2883365, 2938609, 2882007, 2880626, 2935852, 2937232, 2935851, 2935818, 2913798, 2912415, 2913797, 2948240, 2945475, 2946858, 2913801, 2911039, 2912419, 2909657, 2909656, 2912420, 2906894, 2913802, 2908276, 2908275, 2915182, 2915183, 2916564, 2916565, 2911038, 2937227, 2931704, 2941412, 2964796, 2928972, 2928973, 2886154, 2886152, 2888916, 2888915, 2888914, 2888913, 2887535, 2890298, 2890299, 2887534, 2887533, 2887532, 2887531, 2886153, 2888917, 2884770, 2888918, 2886151, 2886150, 2884768, 2884769, 2869548, 2962022, 2963403, 2949593, 2948210, 2927573, 2877836, 2938655, 2948328, 2927592, 2869570, 2876458, 2877841, 2952387, 2951003, 2949622, 2951004, 2868169, 2890295, 2890293, 2894441, 2894443, 2894445, 2894446, 2890294, 2895824, 2895825, 2895826]
rg = 1
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}-clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)

''' RECOMMENDER '''
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]
weights = {
    'popden_wom': 2,
    'popden_chi': 2,
    'popden_w_1': 2,
    'popden_you': 1,
    'popden_eld': 1
}
# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')
# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])
# Load the trained models and make predictions on the new dataset
for name in ['Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score','Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in ['Neural_Network']}

for name in ['Neural_Network']:
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()
      if num_rhus > 0:
        print(f"{city} - {num_rhus} rhus needed")
        print(recommended_locations[name][city])

# all_locations = []
# for name in models.keys():
#   model_locations = []
#   print(f"Model: {name}")
#   for city, locations in recommended_locations[name].items():
#     if locations != []:
#       print(f"Recommended locations for {city}: {locations}")
#       model_locations.append(locations)
#   all_locations.append(model_locations)
# Out:
# <ipython-input-6-629443726b4d>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-6-629443726b4d>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-6-629443726b4d>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 2

# %%
os = [3101697, 3091970, 3096170, 3091975, 3091976, 3087879, 3087880, 3096171, 3087884, 3096077, 3087886, 3087885, 3091986, 3091987, 3091988, 3091989, 3091990, 3054612, 3096089, 3096090, 3119643, 3105819, 3127840, 3127841, 3074082, 3074084, 3074086, 3046438, 3074088, 3127850, 3100208, 3100209, 3092022, 3092024, 3092025, 3082298, 3082299, 3092026, 3082301, 3100223, 3096133, 3096134, 3096136, 3096137, 3096138, 3058765, 3058768, 3109970, 3109971, 3109974, 3078231, 3109976, 3109975, 3086427, 3104354, 3104356, 3104357, 3104358, 3090535, 3090536, 3127913, 3127914, 3086443, 3127912, 3086445, 3086446, 3127911, 3086448, 3123820, 3086450, 3086451, 3090548, 3090549, 3090547, 3096174, 3086457, 3100282, 3082367, 3090560, 3114116, 3100294, 3114120, 3068553, 3068554, 3068555, 3068556, 3054732, 3114121, 3068560, 3108496, 3108498, 3108499, 3108500, 3108501, 3090593, 3090596, 3094693, 3094692, 3086502, 3086503, 3067049, 3090606, 3094706, 3094707, 3118260, 3104437, 3104438, 3094708, 3072698, 3126458, 3072699, 3126459, 3031229, 3031230, 3072703, 3072704, 3045057, 3072700, 3072701, 3072708, 3098826, 3098827, 3136204, 3080910, 3090643, 3090644, 3090650, 3090651, 3094749, 3094750, 3094751, 3094752, 3094753, 3130606, 3130607, 3130608, 3076849, 3130609, 3102973, 3102974, 3102975, 3126530, 3126531, 3094787, 3094789, 3094790, 3085063, 3085064, 3085065, 3085066, 3089163, 3094791, 3094792, 3085072, 3085076, 3098901, 3098900, 3080984, 3061529, 3112734, 3097549, 3053346, 3067171, 3067172, 3053347, 3112741, 3112740, 3089192, 3107117, 3107118, 3107119, 3107120, 3107121, 3098933, 3126582, 3089208, 3089209, 3085113, 3089211, 3089210, 3093311, 3093312, 3085119, 3085120, 3085121, 3103044, 3065668, 3089223, 3093324, 3116878, 3103055, 3103056, 3103057, 3093328, 3071316, 3071317, 3071318, 3057495, 3071320, 3071321, 3071322, 3071319, 3111261, 3111262, 3079529, 3079530, 3089261, 3089262, 3097459, 3089268, 3089267, 3093370, 3093371, 3093372, 3097470, 3097471, 3097472, 3129223, 3129224, 3075465, 3075467, 3047820, 3047819, 3047821, 3115404, 3075472, 3129232, 3101591, 3083678, 3083679, 3083680, 3083681, 3093410, 3083683, 3083684, 3093411, 3093409, 3093408, 3093407, 3060135, 3097518, 3097519, 3079604, 3079605, 3111352, 3111356, 3111357, 3111358, 3111359, 3046338, 3105734, 3105736, 3105738, 3091917, 3097550, 3097551, 3129296, 3087825, 3087826, 3087827, 3087828, 3087829, 3097553, 3101662, 3101664, 3101665, 3101666, 3115498, 3091946, 3115503, 3069936, 3069937, 3115505, 3115504, 3109879, 3109883, 3096168]
rg = 2
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)

''' RECOMMENDER '''
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')
# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])
# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-18-e980d83bb7d9>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-18-e980d83bb7d9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-18-e980d83bb7d9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 3

# %%
os = [2899997, 2900001, 2900002, 2900003, 2900004, 2900005, 2900006, 2900007, 2900008, 2900009, 2900010, 2905573, 2905572, 2905574, 2905575, 2904131, 2904139, 2904140, 2904141, 2904142, 2904143, 2904144, 2904145, 2904146, 2904147, 2904148, 2900052, 2904150, 2904149, 2904152, 2904153, 2900051, 2904155, 2904154, 2898664, 2904176, 2908279, 2908283, 2904188, 2908285, 2908286, 2908287, 2908288, 2908289, 2908290, 2908291, 2908284, 2908293, 2908294, 2908295, 2908296, 2908297, 2908298, 2908299, 2908300, 2908301, 2904198, 2908303, 2908304, 2908309, 2912430, 2912431, 2912432, 2912433, 2912434, 2912435, 2912436, 2912437, 2912438, 2912439, 2912440, 2912441, 2912442, 2912443, 2912444, 2912445, 2912446, 2912447, 3027136, 2908344, 3027138, 3027139, 3027140, 3027141, 3027142, 3027143, 3027144, 2912466, 2916578, 2916579, 2916580, 2916581, 3027174, 2916583, 2916584, 3027175, 2916586, 2916587, 2916589, 2916590, 2916591, 2916592, 2916593, 3027185, 2920728, 2920731, 2920732, 2920733, 2920735, 2920736, 2916641, 2920738, 2920739, 2920742, 2920755, 2920770, 2924872, 2924874, 2924876, 2924878, 2924879, 2924887, 2924888, 2924889, 2924904, 2924905, 2924906, 2929044, 2929048, 2929049, 2929050, 2929051, 2929052, 2929053, 2929054, 2929055, 2929056, 2929063, 2929075, 3107253, 2933195, 2933197, 2933198, 2933202, 2933226, 2933228, 2894476, 2894477, 2894479, 2898601, 2898615, 2898618, 2898619, 2898620, 2898621, 2898622, 2898623, 2898624, 2898625, 2898626, 2898627, 2902759, 2902760, 2902761, 2902762, 2902763, 2898665, 2902765, 2902766, 2902767, 2902768, 2902769, 2902770, 2902771, 2902772, 2902794, 2902806, 2902807, 2902808, 2902809, 2902810, 2902811, 2902812, 2902813, 2906906, 2902815, 2906911, 2906910, 2906914, 2906915, 2906916, 2906909, 2911048, 2911049, 2911050, 2911051, 2911052, 2911053, 2911054, 2911055, 2911056, 2911057, 2911058, 2911059, 2911060, 2911061, 2911062, 2911063, 2911064, 2911065, 2911066, 2911067, 2906964, 2906959, 2906960, 2911087, 2906961, 2911090, 2911092, 2906962, 2915194, 2915195, 2915196, 2915197, 2915198, 2915199, 2906963, 2915201, 2915202, 2915203, 2915204, 2915205, 2915206, 2915207, 2915208, 2915209, 2900048, 2900049, 2900050, 2919342, 2919347, 2919348, 2919349, 2919351, 2919352, 2919353, 2919354, 2919355, 2919360, 2919361, 2919374, 2923491, 2923494, 2923496, 2923499, 2923500, 2923503, 2923505, 2923507, 2923519, 2923523, 2927645, 2927665, 2927668, 2927669, 2927670, 2927671, 2927672, 2927673, 2927674, 2927675, 2927681, 3105871, 3105872, 2927697, 2931810, 2931811, 2931812, 2931816, 2931817, 2931818, 2931840, 2931842, 2931846, 2904189, 2904190, 2904191, 2904192, 2904193, 2904194, 2904195, 2904196, 2904197, 2897219, 2897229, 2897236, 2897237, 2897238, 2897239, 2897240, 2897241, 2897242, 2897243, 2897244, 2897245, 2897246, 2897247, 2897280, 2901377, 2901378, 2901379, 2897281, 2897282, 2901384, 2901385, 2901386, 2901387, 2901388, 2901389, 2901390, 2901391, 2908292, 2901424, 2905522, 2905523, 2905524, 2901429, 2901430, 2901431, 2901432, 2901433, 2901434, 2905531, 2905530, 2905533, 2905534, 2905535, 2905536, 2905529, 2905559, 2909661, 2909665, 2909666, 2909667, 2909668, 2909669, 2909670, 2909671, 2909672, 2909673, 2909674, 2909675, 2909676, 2909677, 2909678, 2909679, 2909680, 2909681, 2909685, 2909686, 2909691, 2909696, 2909705, 2909709, 2909710, 2913812, 2913813, 2913814, 2913815, 2913817, 2913818, 2913819, 2913820, 2913821, 2913822, 2913823, 2913824, 2913825, 2913826, 2913827, 2909725, 2913829, 2913830, 2913831, 2913849, 2913850, 2917964, 2917965, 2917967, 2917970, 2917971, 2917972, 2917973, 2917975, 2917976, 2917977, 2922110, 2922114, 2922117, 2922118, 2922119, 2922120, 2908340, 2922124, 2922125, 2908341, 2908342, 2922137, 2922138, 2908343, 2922153, 2926254, 2926260, 2926262, 2926269, 2926270, 2926283, 2926285, 2926286, 2926287, 3045100, 2930416, 2930430, 2930431, 2930433, 2930434, 2930435, 2930436, 2930437, 2930457, 2930458, 2934576, 2934579, 2905525, 2905526, 2934589, 2934590, 2905527, 2905528, 2934605, 2934607, 2934608, 2934620, 2895847, 2895854, 2895855, 2895857, 2895858, 2895859, 2895860, 2895861, 2895863]
rg = 3
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)

''' RECOMMENDER '''
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')
# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])
# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-18-e980d83bb7d9>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-18-e980d83bb7d9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-18-e980d83bb7d9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 4a

# %%
os = [3006483, 3006499, 3006501, 3006502, 3006503, 3006507, 3006511, 3006512, 3006515, 3006517, 3006518, 3006521, 3006526, 3006532, 3006542, 3014758, 3014769, 3014770, 3014771, 3014773, 3014775, 3014776, 3014777, 3014778, 3014795, 3014796, 3014798, 3014799, 3014807, 3023047, 3023049, 3023050, 3023051, 3023067, 3023079, 3023080, 3023090, 3023093, 3023119, 3031334, 3031339, 3031340, 3031341, 3031342, 3031343, 3031344, 3031347, 3031348, 3031358, 3031360, 3031361, 3031362, 3031365, 3031366, 3031367, 3031368, 3031369, 3031370, 3031371, 3031373, 3031377, 3031378, 3031379, 3031380, 3031381, 3039629, 3039630, 3039631, 3039632, 3039633, 3039634, 3039635, 3039636, 3039637, 3039638, 3039639, 3039640, 3039641, 3039642, 3039643, 3039651, 3039652, 3039655, 3039656, 3039658, 3039667, 3039668, 3039669, 3039670, 3039671, 3039672, 3039674, 3039675, 3039676, 3039677, 3039678, 3039679, 3047926, 3047932, 3047933, 3047934, 3047936, 3047937, 3047939, 3047941, 3047942, 3047943, 3047944, 3047945, 3047947, 3047949, 3047950, 3047951, 3047952, 3047953, 3047955, 3047956, 3047958, 3047959, 3047961, 3047962, 3047965, 3047966, 3047967, 3047968, 3047969, 3047970, 3047971, 3047974, 3047975, 3047976, 3047977, 3047978, 3047979, 3047980, 3047981, 3047983, 3047984, 3056222, 3056224, 3056225, 3056226, 3056227, 3056228, 3056229, 3056230, 3056231, 3056232, 3056233, 3056235, 3056236, 3056237, 3056238, 3056239, 3056240, 3056241, 3056242, 3056243, 3056244, 3056245, 3056246, 3056247, 3056248, 3056249, 3056250, 3056251, 3056252, 3056253, 3056254, 3056257, 3056258, 3056260, 3056266, 3056267, 3056268, 3056270, 3056273, 3056276, 3056277, 3064533, 3064534, 3064535, 3064536, 3064537, 3064538, 3064539, 3064540, 3064541, 3064542, 3064543, 3064544, 3064545, 3064546, 3064547, 3064565, 3064567, 2958134, 2958135, 2966422, 2974717, 2974726, 2982993, 2983011, 2983012, 2983015, 2983028, 2983029, 2983044, 2983049, 2991291, 2991293, 2991306, 2991308, 2991311, 2991315, 2991318, 2991323, 2991324, 2991325, 2991326, 2991330, 2991331, 2991332, 2991333, 2999584, 2999598, 2999599, 2999600, 2999601, 2999614, 2999615, 2999616, 2999617, 2999618, 2999633, 3007865, 3007879, 3007884, 3007885, 3007886, 3007889, 3007890, 3007891, 3007893, 3007894, 3007898, 3007900, 3007907, 3007910, 3007917, 3016151, 3016152, 3016159, 3016160, 3016161, 3016162, 3016180, 3016181, 3016184, 3016216, 3024429, 3024431, 3024432, 3024433, 3024447, 3024451, 3024472, 3024473, 3032721, 3032722, 3032723, 3032724, 3032727, 3032728, 3032729, 3032739, 3032742, 3032743, 3032746, 3032750, 3032751, 3032752, 3032753, 3032754, 3032755, 3032759, 3032760, 3032761, 3032762, 3032763, 3032768, 3032770, 3032771, 3041013, 3041014, 3041015, 3041016, 3041017, 3041018, 3041020, 3041021, 3041022, 3041023, 3041024, 3041026, 3041027, 3041030, 3041032, 3041035, 3041037, 3041039, 3041040, 3041041, 3041050, 3041052, 3041053, 3041054, 3041055, 3041056, 3041057, 3041058, 3041059, 3041062, 3041066, 3041068, 3041087, 3049309, 3049310, 3049311, 3049312, 3049313, 3049314, 3049316, 3049317, 3049319, 3049320, 3049321, 3049323, 3049324, 3049325, 3049326, 3049329, 3049330, 3049331, 3049332, 3049333, 3049334, 3049335, 3049337, 3049338, 3049340, 3049343, 3049344, 3049345, 3049347, 3049348, 3049350, 3049351, 3049352, 3049353, 3049356, 3049357, 3049358, 3049360, 3049362, 3049363, 3049365, 3057608, 3057611, 3057612, 3057613, 3057614, 3057618, 3057619, 3057620, 3057621, 3057622, 3057623, 3057624, 3057625, 3057626, 3057627, 3057628, 3057629, 3057630, 3057631, 3057632, 3057633, 3057634, 3057636, 3057637, 3057639, 3057640, 3057648, 3057649, 3057650, 3057652, 3057654, 3057655, 3057660, 3065895, 3065919, 3065920, 2959511, 2959514, 2959516, 2967803, 2976101, 2976102, 2976107, 2984373, 2984394, 2984398, 2984400, 2984404, 2984423, 2984424, 2984425, 2984426, 2984427, 2984429, 2984430, 2992666, 2992697, 2992704, 2992705, 2992706, 2992707, 2992709, 2992711, 2992712, 2992713, 3000966, 3000967, 3000968, 3000973, 3000980, 3000982, 3000988, 3000995, 3000997, 3000998, 3001000, 3001006, 3001007, 3001010, 3001013, 3001020, 3009245, 3009262, 3009269, 3009270, 3009276, 3009279, 3009280, 3009283, 3009287, 3009288, 3017522, 3017540, 3017541, 3017542, 3017543, 3017545, 3017551, 3017552, 3017562, 3017563, 3017564, 3017565, 3017596, 3017597, 3025810, 3025811, 3025812, 3025813, 3025814, 3025815, 3025832, 3025853, 3025854, 3025855, 3025882, 3034104, 3034105, 3034106, 3034109, 3034110, 3034113, 3034114, 3034122, 3034123, 3034124, 3034125, 3034128, 3034132, 3034134, 3034135, 3034136, 3034140, 3034141, 3034142, 3034144, 3034146, 3034149, 3034150, 3034151, 3034174, 3034175, 3034179, 3034181, 3042375, 3042394, 3042395, 3042396, 3042397, 3042398, 3042399, 3042400, 3042403, 3042404, 3042405, 3042406, 3042408, 3042411, 3042412, 3042413, 3042414, 3042415, 3042416, 3042417, 3042418, 3042419, 3042420, 3042421, 3042422, 3042428, 3042430, 3042431, 3042432, 3042433, 3042436, 3042439, 3042440, 3042441, 3042442, 3042447, 3042448, 3042449, 3050676, 3050678, 3050679, 3050691, 3050692, 3050693, 3050694, 3050695, 3050697, 3050698, 3050699, 3050701, 3050702, 3050703, 3050704, 3050705, 3050706, 3050709, 3050710, 3050711, 3050712, 3050714, 3050715, 3050716, 3050718, 3050720, 3050722, 3050725, 3050729, 3050730, 3050732, 3050737, 3050738, 3050739, 3050740, 3050743, 3050744, 3050746, 3050748, 3058984, 3058986, 3058987, 3058989, 3058990, 3058997, 3058999, 3059000, 3059002, 3059003, 3059004, 3059005, 3059006, 3059007, 3059008, 3059009, 3059010, 3059011, 3059012, 3059013, 3059014, 3059015, 3059016, 3059017, 3059019, 3059020, 3059021, 3059022, 3059024, 3059028, 3059030, 3059031, 3059033, 3059037, 3059041, 2952609, 2960895, 2960899, 2969186, 2977490, 2985775, 2985781, 2985782, 2985783, 2985785, 2985786, 2985789, 2985795, 2985798, 2985801, 2985806, 2985807, 2985809, 2985812, 2985814, 2994065, 2994067, 2994071, 2994072, 2994075, 2994080, 2994081, 2994086, 2994087, 2994088, 2994090, 2994091, 2994093, 2994094, 3002348, 3002350, 3002354, 3002356, 3002357, 3002359, 3002365, 3002366, 3002367, 3002371, 3002377, 3002398, 3002402, 3010628, 3010629, 3010630, 3010647, 3010648, 3010652, 3010653, 3010657, 3010665, 3018905, 3018906, 3018929, 3018930, 3018931, 3018932, 3018933, 3018934, 3018935, 3018936, 3018944, 3018945, 3018946, 3018948, 3018949, 3018950, 3018980, 3027194, 3027195, 3027196, 3027197, 3027198, 3027214, 3027217, 3027227, 3027228, 3027229, 3027237, 3027241, 3035487, 3035488, 3035489, 3035490, 3035491, 3035493, 3035494, 3035496, 3035497, 3035502, 3035503, 3035504, 3035506, 3035508, 3035511, 3035513, 3035514, 3035516, 3035517, 3035518, 3035523, 3035524, 3035526, 3035527, 3035528, 3035530, 3035531, 3035532, 3035533, 3035537, 3043776, 3043780, 3043781, 3043782, 3043783, 3043784, 3043785, 3043786, 3043787, 3043788, 3043789, 3043790, 3043791, 3043793, 3043794, 3043798, 3043799, 3043800, 3043803, 3043804, 3043805, 3043806, 3043812, 3043813, 3043814, 3043815, 3043816, 3043818, 3043822, 3043823, 3043829, 3043832, 3052072, 3052073, 3052074, 3052075, 3052076, 3052077, 3052078, 3052079, 3052080, 3052081, 3052082, 3052083, 3052085, 3052086, 3052087, 3052088, 3052089, 3052090, 3052091, 3052092, 3052093, 3052094, 3052095, 3052096, 3052098, 3052101, 3052103, 3052105, 3052106, 3052107, 3052109, 3052112, 3052115, 3052117, 3052120, 3052122, 3052123, 3052124, 3052125, 3052127, 3052128, 3052131, 3052132, 3052133, 3060366, 3060377, 3060378, 3060380, 3060383, 3060384, 3060385, 3060386, 3060387, 3060388, 3060389, 3060390, 3060391, 3060392, 3060393, 3060394, 3060395, 3060396, 3060397, 3060398, 3060399, 3060400, 3060401, 3060402, 3060403, 3060407, 3060411, 3060413, 3060414, 3060416, 3060421, 2953992, 2962275, 2962281, 2962284, 2970573, 2970574, 2978873, 2978874, 2987159, 2987162, 2987163, 2987164, 2987165, 2987166, 2987167, 2987168, 2987171, 2987181, 2987184, 2987187, 2987188, 2987189, 2987190, 2987193, 2995454, 2995455, 2995456, 2995457, 2995461, 2995462, 2995471, 2995473, 2995474, 2995475, 2995477, 3003734, 3003735, 3003737, 3003738, 3003745, 3003746, 3003747, 3003749, 3003750, 3003751, 3003752, 3003756, 3003775, 3003776, 3003777, 3003778, 3003783, 3003784, 3003785, 3012007, 3012010, 3012011, 3012028, 3012029, 3012031, 3012033, 3012034, 3012035, 3012036, 3012037, 3012039, 3012042, 3012045, 3020284, 3020293, 3020294, 3020295, 3020296, 3020313, 3020314, 3020315, 3020317, 3020318, 3020325, 3020327, 3020328, 3020330, 3020341, 3020342, 3020356, 3020363, 3028577, 3028578, 3028579, 3028580, 3028582, 3028587, 3028598, 3028606, 3028607, 3028608, 3028609, 3028610, 3028611, 3028615, 3028616, 3028617, 3028619, 3028648, 3036852, 3036868, 3036869, 3036870, 3036871, 3036872, 3036873, 3036874, 3036875, 3036877, 3036879, 3036880, 3036883, 3036885, 3036886, 3036887, 3036888, 3036889, 3036890, 3036892, 3036893, 3036895, 3036896, 3036897, 3036898, 3036899, 3036903, 3036904, 3036905, 3036906, 3036907, 3036908, 3036909, 3036910, 3036913, 3036914, 3036921, 3036934, 3045162, 3045163, 3045165, 3045166, 3045167, 3045169, 3045170, 3045171, 3045174, 3045175, 3045176, 3045178, 3045179, 3045180, 3045181, 3045186, 3045187, 3045188, 3045189, 3045191, 3045192, 3045193, 3045194, 3045200, 3045201, 3045204, 3045205, 3045210, 3045211, 3045212, 3045214, 3045215, 3045216, 3053453, 3053454, 3053455, 3053456, 3053457, 3053458, 3053459, 3053460, 3053461, 3053462, 3053463, 3053464, 3053465, 3053466, 3053467, 3053468, 3053469, 3053470, 3053472, 3053473, 3053474, 3053475, 3053476, 3053477, 3053478, 3053479, 3053482, 3053483, 3053484, 3053485, 3053486, 3053487, 3053492, 3053493, 3053494, 3053497, 3053498, 3053499, 3053500, 3053501, 3053502, 3053504, 3053508, 3053509, 3053510, 3053511, 3053513, 3061750, 3061762, 3061764, 3061767, 3061768, 3061769, 3061770, 3061771, 3061772, 3061773, 3061774, 3061775, 3061776, 3061777, 3061778, 3061779, 3061780, 3061781, 3061782, 3061783, 3061787, 3061788, 3061789, 3061791, 3061794, 3061798, 3061799, 3061802, 3061804, 2963664, 2980249, 2980250, 2980255, 2980259, 2980283, 2988522, 2988535, 2988540, 2988542, 2988544, 2988545, 2988546, 2988548, 2988551, 2988552, 2988556, 2988557, 2988563, 2988566, 2988568, 2988569, 2988570, 2988571, 2988576, 2988577, 2996821, 2996822, 2996826, 2996833, 2996835, 2996836, 2996839, 2996843, 2996852, 2996853, 2996854, 2996856, 2996857, 2996858, 3005119, 3005128, 3005129, 3005130, 3005131, 3005133, 3005134, 3005135, 3005136, 3005137, 3005138, 3005160, 3005166, 3005167, 3005168, 3013395, 3013411, 3013412, 3013414, 3013415, 3013416, 3013417, 3013448, 3021665, 3021666, 3021673, 3021677, 3021697, 3021698, 3021700, 3021708, 3021709, 3021718, 3021723, 3029956, 3029959, 3029960, 3029961, 3029962, 3029963, 3029969, 3029973, 3029979, 3029980, 3029982, 3029983, 3029984, 3029987, 3029988, 3029990, 3029991, 3029992, 3029993, 3029998, 3029999, 3030003, 3030027, 3030028, 3030033, 3038251, 3038252, 3038253, 3038254, 3038255, 3038256, 3038257, 3038258, 3038259, 3038260, 3038261, 3038265, 3038267, 3038269, 3038272, 3038273, 3038275, 3038276, 3038277, 3038278, 3038279, 3038280, 3038285, 3038286, 3038287, 3038288, 3038289, 3038290, 3038292, 3038293, 3038294, 3038295, 3038296, 3038297, 3038299, 3038300, 3046527, 3046550, 3046551, 3046552, 3046553, 3046554, 3046555, 3046556, 3046558, 3046561, 3046562, 3046563, 3046564, 3046568, 3046570, 3046571, 3046572, 3046573, 3046574, 3046576, 3046577, 3046579, 3046580, 3046581, 3046584, 3046586, 3046587, 3046589, 3046592, 3046593, 3046594, 3046595, 3046600, 3046607, 3054833, 3054836, 3054837, 3054838, 3054840, 3054841, 3054843, 3054844, 3054845, 3054846, 3054847, 3054848, 3054850, 3054851, 3054852, 3054854, 3054855, 3054856, 3054857, 3054858, 3054859, 3054860, 3054861, 3054862, 3054863, 3054865, 3054866, 3054867, 3054868, 3054869, 3054870, 3054871, 3054880, 3054881, 3054883, 3054887, 3054888, 3054889, 3054891, 3054892, 3054893, 3054895, 3063148, 3063149, 3063151, 3063152, 3063153, 3063154, 3063155, 3063156, 3063157, 3063158, 3063159, 3063160, 3063161, 3063162, 3063163, 3063164, 3063165, 3063169, 3063181, 3063185, 3063186, 3063187, 2956752, 2956755, 2956778, 2965039, 2973332, 2973338, 2981613, 2981633, 2981665, 2981666, 2989920, 2989925, 2989926, 2989927, 2989931, 2989932, 2989933, 2989934, 2989935, 2989936, 2989941, 2989942, 2989943, 2989944, 2989945, 2989947, 2989948, 2989949, 2989951, 2998202, 2998217, 2998219, 2998220, 2998234, 2998235, 2998236, 2998237, 2998242]
x = f"{data_dir}/preliminary site selection/CALABARZON/calabarzon_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

def process_population_density(rg1_clustered_df, os, a=1.65):
    # Filtering the DataFrame using the list of IDs
    os_df = rg1_clustered_df[rg1_clustered_df['ID'].isin(os)]

    # Population density columns
    all_pd = os_df['popden_all']
    women_pd = os_df['popden_wom']
    womenrep_pd = os_df['popden_w_1']
    youth_pd = os_df['popden_you']
    elder_pd = os_df['popden_eld']
    children_pd = os_df['popden_chi']

    # Calculating total population based on the multiplier 'a'
    os_df['total_population'] = all_pd * a
    os_df['total_population_women'] = women_pd * a
    os_df['total_population_womenrep'] = womenrep_pd * a
    os_df['total_population_youth'] = youth_pd * a
    os_df['total_population_elderly'] = elder_pd * a
    os_df['total_population_children'] = children_pd * a

    return os_df

os_df = process_population_density(rg1_clustered_df, os)

def HCI_calc(total_ai, total_gi, total_hi, total_ji, total_ki, total_mi,distance, road_bi, POI_ci, landCov_di, hazard1_ei, hazard2_ei, hazard3_ei, rhus_fi):
    total_vulnerable = total_gi + total_hi + total_ji + total_ki + total_mi
    total_pop = total_ai
    population_to_be_served = total_vulnerable + np.maximum(0, total_pop - total_vulnerable)
    # Calculate y for the entire Series without using if condition
    y = np.where(population_to_be_served == 0, 0, 20000 / ((population_to_be_served) * (distance + rhus_fi)))
    mc = np.tanh(y)
    w_bi = 0.3 # roads
    w_ci = 0.2 # POIs
    w_di = 0.5 # land cov
    b = (POI_ci * w_ci) + (road_bi * w_bi) + (landCov_di * w_di)
    # Normalize each factor
    rain_intensity_normalized = (hazard1_ei - hazard1_ei.min()) / (hazard1_ei.max() - hazard1_ei.min())
    flood_probability_normalized = (hazard2_ei - hazard2_ei.min()) / (hazard2_ei.max() - hazard2_ei.min())
    drought_mean_normalized = (hazard3_ei - hazard3_ei.min()) / (hazard3_ei.max() - hazard3_ei.min())
    w_rain = 0.4
    w_flood = 0.3
    w_drought = 0.3
    c = (w_rain * rain_intensity_normalized) + (w_flood * flood_probability_normalized) + (w_drought * drought_mean_normalized)
    f = b - c
    f = np.tanh(f)
    hci = mc * f
    hcfai = (1 + np.tanh(hci / 2)) / 2  # Sigmoid function
    return hcfai
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)

# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load('scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
# for name in ['Neural_Network']:
    model = joblib.load(f'{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

# Print recommended locations for each city by each model
all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-37-6577a325f305>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-37-6577a325f305>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-37-6577a325f305>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 4b

# %%
os = [3090951, 2829835, 3150348, 3108892, 2843662, 2843663, 3099152, 3164176, 2843664, 2829843, 3108884, 3108885, 2843667, 2857495, 2879511, 2893337, 2998298, 3108891, 2998299, 2879517, 2998300, 3108888, 3108890, 2893345, 3108889, 2893347, 2893348, 2998303, 2984484, 2833959, 2988588, 2988592, 2988593, 2820154, 2820157, 3016255, 3089472, 3168320, 3168321, 3016257, 3016256, 3154501, 2911298, 2847808, 3113032, 2847812, 2897484, 2988626, 2988631, 2838108, 2992733, 2883676, 2992735, 2992736, 2838113, 2992737, 2992738, 2992739, 2992732, 2992740, 3099237, 3158639, 3034224, 3020402, 3020403, 3107445, 3020406, 3107447, 3158647, 2824313, 3020410, 2851964, 3020413, 2873983, 2901631, 2901633, 3093632, 2992775, 2887816, 2887817, 2887821, 2887822, 2978957, 2842259, 2842260, 3107476, 2828438, 2828439, 2828440, 2828441, 3107478, 2996886, 3038357, 2998302, 3038358, 2891932, 3006625, 3006627, 2828458, 2828459, 2828460, 3162797, 3162798, 2842282, 2842284, 2878129, 3010737, 3107502, 2878132, 2891957, 2891958, 2878135, 2891956, 2996919, 2996916, 2996920, 2996921, 2996883, 2983102, 2983103, 3093695, 3014849, 2987204, 2987205, 3042505, 2896080, 3093716, 3153111, 3014873, 2846426, 2846427, 3101916, 2846428, 3014878, 3014879, 3088098, 3101925, 2896102, 3001062, 2896105, 2987243, 2896109, 2896110, 2987246, 2987248, 2987247, 3039738, 3039739, 2991354, 2991356, 2991357, 2991358, 3001094, 3171081, 3092235, 2805005, 3106062, 2805008, 2822930, 2822931, 2872602, 2900251, 2900250, 2991389, 2991391, 2886437, 2886439, 3106094, 3106095, 2926384, 3036975, 2995503, 3102001, 2890551, 2890552, 2876734, 2918208, 2840897, 2840898, 2876736, 3009348, 3009349, 2827077, 3161415, 3161414, 3106121, 2854730, 2854731, 2876746, 2904396, 2876750, 2876751, 2876752, 2890575, 2995537, 2995534, 2890580, 2890581, 2995538, 2995539, 2890584, 2981720, 2890586, 2985823, 3041120, 3041122, 2831203, 3108858, 2930532, 3041124, 2894699, 2831217, 2831218, 2845046, 2845049, 3110266, 3086715, 2845050, 2880894, 3110272, 3110273, 3110274, 2894722, 2894728, 2894729, 2985864, 3106119, 2989967, 2989969, 3031443, 2989972, 3106120, 2989974, 2920855, 2835352, 2821536, 3169698, 2821539, 3155875, 3017639, 2912680, 2849193, 2849194, 3090856, 2821548, 2898865, 2898868, 3103379, 2990007, 2990010, 2990011, 2885054, 2885056, 2994116, 2994118, 2994119, 3035592, 2994122, 3100619, 2994124, 3132378, 3132379, 3108827, 2825694, 2825695, 2825696, 3160032, 2998266, 2853347, 3160033, 3104738, 2903015, 2903016, 2994153, 3108886, 2889200, 2980337, 2889204, 2998270, 3039737, 2829818, 2829819, 3039741, 2829822]
rg = 'mimaropa'
x = f"{data_dir}/preliminary site selection/MIMAROPA/{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-37-6577a325f305>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-37-6577a325f305>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-37-6577a325f305>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 5

# %%
os = [3278865, 3282962, 3282966, 3282967, 3282970, 3282975, 3287075, 3287081, 3287082, 3287083, 3287110, 3287113, 3287115, 3287123, 3350643, 3350646, 3291260, 3240069, 3240071, 3240072, 3240073, 3240082, 3240097, 3240098, 3240100, 3295416, 3244228, 3240133, 3240134, 3240132, 3240135, 3240137, 3240138, 3240139, 3240140, 3240141, 3240142, 3244241, 3244242, 3244243, 3244244, 3244246, 3244274, 3244282, 3244283, 3248378, 3244285, 3248389, 3248390, 3248391, 3248392, 3244326, 3252520, 3252523, 3252524, 3252525, 3252526, 3252550, 3269134, 3256668, 3256669, 3256670, 3256671, 3256672, 3256673, 3269141, 3260811, 3260813, 3260814, 3260815, 3260816, 3260817, 3260818, 3260819, 3260820, 3260837, 3260838, 3264953, 3264954, 3264955, 3320252, 3320253, 3320254, 3320255, 3320256, 3264961, 3264962, 3264963, 3264964, 3264965, 3260861, 3264967, 3264968, 3264969, 3264984, 3264985, 3264986, 3264987, 3264988, 3320281, 3264990, 3264991, 3320286, 3264989, 3264992, 3324388, 3324389, 3324396, 3324397, 3324398, 3324402, 3269107, 3269108, 3269109, 3269110, 3269113, 3269114, 3269115, 3328522, 3328523, 3324428, 3324429, 3328525, 3269135, 3269136, 3269137, 3269138, 3269139, 3269140, 3328526, 3269142, 3269143, 3328536, 3328537, 3328538, 3328539, 3328540, 3328541, 3328542, 3328543, 3328548, 3273256, 3273257, 3273261, 3273262, 3332667, 3332668, 3332669, 3332670, 3273279, 3328577, 3328578, 3273283, 3273284, 3273285, 3273286, 3328579, 3332679, 3332681, 3332682, 3332680, 3273289, 3273292, 3273287, 3332687, 3332688, 3332692, 3332693, 3332694, 3269208, 3277404, 3277405, 3277406, 3273334, 3277431, 3273336, 3277433, 3277437, 3277438, 3277439, 3277440, 3277441, 3277442, 3277445, 3281548, 3281551, 3281552, 3281554, 3273369, 3273370, 3281578, 3281581, 3281582, 3281587, 3281589, 3281593, 3285697, 3285698, 3285699, 3285730, 3285732, 3285733, 3285740, 3289839, 3289876, 3238686, 3238688, 3353413, 3294023, 3294025, 3242837, 3238751, 3242848, 3242849, 3238753, 3238755, 3238756, 3238754, 3238752, 3238757, 3242860, 3242861, 3242862, 3242863, 3298169, 3242892, 3242900, 3242901, 3246996, 3242903, 3242904, 3247006, 3247007, 3247008, 3247009, 3247011, 3251141, 3251142, 3251143, 3247048, 3251153, 3251155, 3251169, 3251183, 3255286, 3255287, 3255288, 3255289, 3255291, 3255292, 3255312, 3259425, 3255332, 3314728, 3259433, 3259434, 3259435, 3259436, 3259437, 3259432, 3259439, 3259453, 3314768, 3263575, 3263576, 3263578, 3263579, 3263580, 3263581, 3263582, 3263583, 3263584, 3263585, 3263586, 3263587, 3263600, 3263601, 3263602, 3263603, 3263604, 3263605, 3263606, 3323010, 3323011, 3323012, 3323013, 3323015, 3323019, 3267725, 3267726, 3267727, 3267728, 3267731, 3267732, 3318931, 3318932, 3270522, 3267752, 3267753, 3323049, 3267755, 3267756, 3267757, 3267758, 3267754, 3267760, 3267761, 3267762, 3267763, 3327151, 3327154, 3327152, 3327155, 3327156, 3327153, 3270526, 3327164, 3327166, 3271873, 3271874, 3271878, 3271879, 3331290, 3327195, 3271900, 3271901, 3271902, 3271903, 3331297, 3331298, 3331299, 3331300, 3271908, 3271907, 3271905, 3331305, 3331306, 3331307, 3331313, 3276021, 3276022, 3276023, 3276024, 3276025, 3276026, 3276027, 3335430, 3335438, 3335439, 3271953, 3271954, 3276051, 3335445, 3276057, 3276058, 3276059, 3276061, 3271972, 3280168, 3280169, 3280170, 3280171, 3280194, 3280196, 3280199, 3280201, 3280202, 3280210, 3280211, 3284315, 3284316, 3284317, 3284318, 3284319, 3284320, 3284347, 3284348, 3284349, 3284350, 3284352, 3284354, 3284356, 3288460, 3288461, 3288462, 3288463, 3288464, 3288465, 3288523, 3288524, 3352028, 3352029, 3292641, 3292642, 3292643, 3352038, 3292653, 3237358, 3237359, 3241456, 3237372, 3292671, 3241479, 3241480, 3296788, 3241512, 3241515, 3241517, 3245613, 3241519, 3241520, 3245614, 3241522, 3245623, 3245624, 3245625, 3245626, 3245627, 3245628, 3245629, 3249759, 3249760, 3245665, 3253905, 3253906, 3253907, 3253908, 3253910, 3253911, 3253932, 3258043, 3313343, 3313344, 3313345, 3258050, 3258051, 3258052, 3258053, 3258054, 3258056, 3258057, 3258075, 3262189, 3262193, 3262197, 3262198, 3262199, 3262200, 3262201, 3262202, 3262203, 3262219, 3262220, 3321630, 3321631, 3321632, 3321633, 3321634, 3266338, 3266339, 3321635, 3321637, 3266343, 3266344, 3266345, 3266346, 3321636, 3266349, 3266350, 3266367, 3266368, 3266369, 3266370, 3321667, 3266372, 3266373, 3266374, 3266375, 3266371, 3266376, 3266378, 3266379, 3266380, 3321677, 3266381, 3325775, 3321679, 3325774, 3325777, 3325772, 3325780, 3325781, 3264960, 3270490, 3270491, 3270492, 3270497, 3321697, 3270515, 3270516, 3270517, 3270518, 3270519, 3266424, 3266425, 3270521, 3270520, 3329916, 3329917, 3329918, 3329919, 3329915, 3270523, 3270525, 3329923, 3329924, 3329925, 3329926, 3329927, 3329928, 3274639, 3274640, 3274641, 3274642, 3274661, 3329960, 3274665, 3274666, 3270571, 3270568, 3334062, 3334063, 3334064, 3334065, 3334066, 3274675, 3274676, 3274674, 3274677, 3274678, 3334075, 3278786, 3278787, 3278788, 3278789, 3278812, 3278813, 3278820, 3278821, 3278822, 3278823, 3278824, 3282934]
rg = 6
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
# for name in ['Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

# Print recommended locations for each city by each model
all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-18-e980d83bb7d9>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-18-e980d83bb7d9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-18-e980d83bb7d9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 6

# %%
os = [3096589, 3104787, 3104788, 3104789, 3104790, 3104791, 3049504, 3049506, 3108932, 3108934, 3108935, 3053643, 3053644, 3108956, 3108958, 3108960, 3108961, 3108965, 3108967, 3108968, 3108969, 3108971, 3113079, 3113080, 3113081, 3113082, 3113083, 3113084, 3113086, 3113087, 3113088, 3113089, 3113090, 3113091, 3113092, 3113093, 3113094, 3113095, 3113096, 3113099, 3113100, 3113101, 3113102, 3113103, 3113104, 3113105, 3113107, 3113108, 3113110, 3113111, 3113112, 3113113, 3113114, 3113115, 3113116, 3113117, 3113118, 3113120, 3117227, 3117228, 3117229, 3117232, 3117233, 3117234, 3117235, 3117236, 3117237, 3117238, 3117239, 3117240, 3117241, 3117242, 3117243, 3117244, 3117245, 3117246, 3117247, 3117248, 3117249, 3117252, 3117254, 3117256, 3117257, 3117258, 3117259, 3117260, 3117261, 3117262, 3117263, 3117264, 3117265, 3117266, 3117267, 3117271, 3117272, 3121373, 3121374, 3121376, 3121377, 3121378, 3121379, 3121380, 3121381, 3121382, 3121383, 3121384, 3121385, 3121386, 3121387, 3121388, 3121389, 3121390, 3121391, 3121392, 3121393, 3121394, 3121395, 3121396, 3121397, 3121398, 3121399, 3121400, 3121401, 3121402, 3121403, 3121404, 3121405, 3121406, 3121407, 3121408, 3121409, 3121410, 3121411, 3121412, 3121413, 3121414, 3121415, 3121416, 3121417, 3125518, 3125519, 3121422, 3121423, 3125526, 3125536, 3125537, 3125544, 3086822, 3086823, 3090968, 3095105, 3095107, 3095108, 3095109, 3095110, 3095111, 3095112, 3039817, 3095113, 3039819, 3095114, 3095115, 3039829, 3039830, 3099254, 3099256, 3099257, 3099258, 3099259, 3099260, 3099261, 3043976, 3043977, 3103403, 3103404, 3103405, 3103406, 3103407, 3048121, 3099353, 3107551, 3107552, 3107553, 3107554, 3052262, 3052263, 3052269, 3107574, 3107575, 3107578, 3107579, 3107580, 3107582, 3107584, 3107586, 3107588, 3107589, 3056408, 3056409, 3111707, 3111708, 3111714, 3111715, 3111716, 3111717, 3111719, 3111721, 3111723, 3111724, 3111728, 3111729, 3111730, 3111731, 3111732, 3111733, 3111734, 3111736, 3115847, 3115849, 3115851, 3115852, 3115853, 3115854, 3115855, 3115856, 3115857, 3115858, 3115859, 3115860, 3115861, 3115862, 3115863, 3115864, 3115865, 3115866, 3115869, 3115871, 3115872, 3115873, 3115874, 3115875, 3115876, 3115877, 3115880, 3115881, 3115882, 3115883, 3115884, 3115885, 3115886, 3115890, 3119989, 3119990, 3119991, 3119992, 3119993, 3119994, 3119995, 3119996, 3119997, 3119998, 3119999, 3120000, 3120001, 3120002, 3120003, 3120004, 3120005, 3120006, 3120007, 3120008, 3120009, 3120010, 3120011, 3120012, 3120013, 3120014, 3120016, 3120017, 3120020, 3120021, 3120022, 3120023, 3120024, 3120025, 3120026, 3120027, 3120028, 3120029, 3120030, 3120031, 3120032, 3120033, 3120034, 3120035, 3120038, 3124153, 3124154, 3085442, 3089579, 3034291, 3093728, 3093729, 3093731, 3093732, 3097873, 3097874, 3097875, 3097876, 3097877, 3097878, 3097879, 3097881, 3042594, 3102020, 3102021, 3102022, 3102023, 3102024, 3102025, 3102026, 3106168, 3106169, 3106170, 3106171, 3106172, 3050888, 3106192, 3106195, 3106196, 3110318, 3055026, 3110331, 3110332, 3110336, 3110341, 3110343, 3110347, 3110350, 3110351, 3110353, 3114463, 3114465, 3114466, 3114467, 3114468, 3114469, 3114470, 3114471, 3114472, 3114473, 3114474, 3114475, 3114476, 3114477, 3114478, 3114479, 3114480, 3114481, 3114482, 3114483, 3114484, 3114485, 3114486, 3114487, 3114488, 3114489, 3114490, 3114492, 3114493, 3114494, 3114495, 3114497, 3114498, 3114499, 3114501, 3114502, 3114503, 3114507, 3114508, 3118612, 3118613, 3118614, 3118616, 3118617, 3118618, 3118619, 3118620, 3118621, 3118622, 3118623, 3118624, 3118625, 3118627, 3118628, 3118629, 3118630, 3118631, 3118632, 3118633, 3118634, 3118635, 3118638, 3118640, 3118641, 3118642, 3118644, 3118645, 3118646, 3118647, 3118648, 3118649, 3118650, 3118651, 3118652, 3118653, 3118654, 3118655, 3118656, 3122753, 3122754, 3122755, 3122757, 3122759, 3122760, 3122761, 3122762, 3122763, 3122764, 3122765, 3122766, 3122767, 3122771, 3088199, 3088202, 3092336, 3092346, 3092348, 3092349, 3037055, 3096491, 3096492, 3096493, 3096494, 3096495, 3096496, 3041201, 3096497, 3096498, 3041214, 3100637, 3100638, 3100639, 3100640, 3100641, 3100642, 3100643, 3100644, 3045357]
rg = 7
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
# for name in ['Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

# Print recommended locations for each city by each model
all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-18-e980d83bb7d9>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-18-e980d83bb7d9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-18-e980d83bb7d9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 7

# %%
os = [3377152, 3377153, 3377154, 3377155, 3377156, 3262465, 3262466, 3262467, 3262473, 3203088, 3203091, 3270679, 3266612, 3266613, 3266614, 3211319, 3274823, 3270752, 3270756, 3330160, 3274868, 3274869, 3278966, 3274871, 3215500, 3215501, 3283100, 3283101, 3283102, 3283103, 3334307, 3283110, 3279020, 3223732, 3219640, 3219641, 3219645, 3219650, 3223755, 3219660, 3283147, 3283148, 3283150, 3283151, 3223761, 3287250, 3287251, 3287252, 3283159, 3283160, 3223770, 3223793, 3223794, 3223795, 3279094, 3227897, 3227898, 3227899, 3227900, 3227901, 3287292, 3287293, 3223811, 3168517, 3287302, 3287303, 3287304, 3342601, 3287305, 3291399, 3291400, 3287309, 3287310, 3291401, 3287313, 3346710, 3346711, 3346717, 3232041, 3232042, 3283242, 3283244, 3291436, 3227950, 3291438, 3227954, 3227955, 3227956, 3291446, 3346746, 3291455, 3287360, 3291458, 3291461, 3346759, 3236170, 3236172, 3236174, 3236175, 3295572, 3236182, 3236183, 3295575, 3236185, 3295576, 3295579, 3295581, 3236190, 3299680, 3299681, 3299682, 3295587, 3295588, 3295592, 3350895, 3350896, 3295602, 3295603, 3350900, 3295604, 3295605, 3295607, 3350907, 3350908, 3240318, 3299712, 3299713, 3299714, 3299715, 3299716, 3299717, 3240326, 3299718, 3240328, 3240329, 3299719, 3299721, 3299723, 3299731, 3295636, 3236246, 3236247, 3355037, 3355038, 3180960, 3355040, 3355041, 3355042, 3355043, 3355045, 3355044, 3299749, 3299750, 3299751, 3299752, 3355052, 3355053, 3355054, 3355055, 3303856, 3359153, 3359151, 3359152, 3303860, 3303861, 3303862, 3303855, 3240393, 3185104, 3299793, 3185106, 3299794, 3299795, 3359190, 3359191, 3359192, 3307993, 3307994, 3308009, 3189247, 3312128, 3189248, 3189250, 3189251, 3248639, 3308039, 3363339, 3248653, 3363345, 3363346, 3363347, 3363348, 3367444, 3316273, 3252792, 3367482, 3367483, 3367484, 3316283, 3316287, 3367488, 3367489, 3367490, 3367491, 3367492, 3367493, 3316294, 3367494, 3367496, 3367495, 3367497, 3367498, 3367499, 3252811, 3252812, 3367503, 3252815, 3316310, 3316318, 3256935, 3371624, 3371625, 3371626, 3371627, 3371628, 3371629, 3197549, 3371631, 3371632, 3371633, 3371634, 3197551, 3197552, 3197553, 3197554, 3197550, 3371635, 3256948, 3256949, 3256950, 3371644, 3256951, 3256952, 3256953, 3375770, 3375771, 3375772, 3375773, 3261088, 3375792, 3269296, 3375797, 3265206, 3265214, 3265215, 3379915, 3265233, 3265236, 3265237, 3273440, 3269352, 3269362, 3269363, 3209977, 3269375, 3277583, 3273495, 3273496, 3273511, 3214121, 3273520, 3332924, 3281724, 3332926, 3332927, 3277632, 3277633, 3277634, 3281725, 3281727, 3281728, 3281729, 3222350, 3218255, 3218256, 3218258, 3218263, 3218264, 3254175, 3218270, 3285866, 3285867, 3337071, 3285871, 3337073, 3281777, 3285873, 3277707, 3222412, 3226517, 3226518, 3222424, 3222425, 3285912, 3285916, 3167135, 3167136, 3167137, 3285920, 3285921, 3285923, 3285924, 3290016, 3285927, 3285928, 3290018, 3290019, 3345336, 3230657, 3290052, 3230663, 3230664, 3290056, 3226574, 3226575, 3294162, 3345364, 3345365, 3345366, 3290076, 3290077, 3345375, 3345376, 3345378, 3234789, 3234790, 3230706, 3294194, 3234804, 3294195, 3294196, 3294197, 3294198, 3294200, 3294203, 3294205, 3294210, 3349511, 3349512, 3349513, 3238935, 3238936, 3238941, 3298334, 3298335, 3238945, 3238946, 3238947, 3298337, 3302443, 3302444, 3298349, 3302445, 3298352, 3353652, 3353655, 3353658, 3353659, 3353660, 3353663, 3298369, 3298370, 3298371, 3298372, 3302471, 3302472, 3302473, 3357770, 3302474, 3243084, 3302475, 3302476, 3302477, 3302478, 3302479, 3302480, 3302481, 3302482, 3302483, 3302484, 3302485, 3353692, 3239005, 3302494, 3302495, 3302498, 3302506, 3357806, 3357807, 3357808, 3357809, 3302512, 3357817, 3357818, 3357819, 3361915, 3361916, 3306625, 3306626, 3306627, 3306628, 3357836, 3247256, 3187865, 3310751, 3187872, 3361954, 3306659, 3361956, 3306663, 3361962, 3361963, 3361964, 3366059, 3310772, 3310773, 3314886, 3314889, 3192010, 3251406, 3314897, 3370198, 3370199, 3251415, 3366105, 3366110, 3366111, 3314912, 3366113, 3366114, 3366112, 3314911, 3366116, 3366115, 3314932, 3196158, 3255554, 3370243, 3370244, 3370245, 3370246, 3370247, 3370248, 3370249, 3196170, 3370251, 3196164, 3196166, 3255565, 3370255, 3370256, 3319058, 3255574, 3374384, 3259699, 3374389, 3374390, 3374391, 3200314, 3200315, 3319099, 3374397, 3259711, 3259712, 3374410, 3263826, 3378533, 3378534, 3263847, 3378536, 3378537, 3263848, 3204469, 3204470, 3204471, 3204472, 3204473, 3272059, 3267968, 3267969, 3267970, 3267971, 3267981, 3267982, 3263896, 3267994, 3267995, 3272110, 3272138, 3280340, 3280341, 3331544, 3331545, 3276250, 3276251, 3280345, 3280346, 3216874, 3216881, 3216882, 3272179, 3284481, 3284482, 3284483, 3335688, 3335689, 3284489, 3284490, 3221023, 3221032, 3276328, 3221034, 3221038, 3221043, 3284533, 3225147, 3262463, 3339837, 3284541, 3284542, 3284544, 3284545, 3288635, 3288636, 3288637, 3343952, 3225172, 3225173, 3225174, 3225175, 3280474, 3229277, 3229278, 3288669, 3229280, 3225185, 3229281, 3225187, 3229282, 3288670, 3288671, 3288672, 3288675, 3288676, 3288684, 3288685, 3343982, 3343983, 3288687, 3288690, 3288693, 3288694, 3288695, 3255555, 3348095, 3233420, 3233421, 3233423, 3292815, 3233425, 3292817, 3292819, 3229332, 3292821, 3292823, 3229337, 3292828, 3292829, 3292830, 3348129, 3348131, 3288741, 3292838, 3292841, 3292843, 3237553, 3237554, 3237557, 3237558, 3296955, 3296956, 3296958, 3296959, 3296960, 3296961, 3301061, 3296966, 3296967, 3296968, 3233481, 3296970, 3301062, 3301063, 3292877, 3301064, 3301065, 3352275, 3352276, 3352277, 3352280, 3296989, 3352290, 3356387, 3356388, 3356389, 3356390, 3241700, 3301093, 3301094, 3301095, 3301096, 3241708, 3301097, 3301098, 3301099, 3301100, 3301102, 3301103, 3301104, 3301106, 3237623, 3237625, 3301113, 3301117, 3301125, 3356425, 3356426, 3356427, 3356428, 3301130, 3301131, 3301133, 3305236, 3360533, 3360534, 3360532, 3305242, 3305243, 3301161, 3360560, 3186483, 3309364, 3186485, 3186484, 3309369, 3360571, 3360573, 3245887, 3364677, 3309387, 3309388, 3245911, 3313504, 3313506, 3364708, 3190629, 3190630, 3250022, 3250024, 3250025, 3190635, 3313519, 3309424, 3368817, 3368818, 3364723, 3364724, 3364725, 3364729, 3313547, 3254160, 3317650, 3368861, 3368862, 3368863, 3368864, 3368865, 3368866, 3194787, 3368868, 3368867, 3368869, 3317671, 3317672, 3368874, 3368875, 3368876, 3317679, 3368880, 3368881, 3371630, 3317696, 3258316, 3258317, 3373007, 3373008, 3373009, 3373010, 3373011, 3373012, 3198933, 3198934, 3198935, 3373015, 3373016, 3317718, 3317719, 3373017, 3258328, 3258329, 3258336, 3377151]
rg = 8
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-18-e980d83bb7d9>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-18-e980d83bb7d9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-18-e980d83bb7d9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 8

# %%
os = [3440640, 3440642, 3436555, 3436556, 3440653, 3436558, 3436557, 3444756, 3436565, 3436564, 3436567, 3461342, 3397858, 3397859, 3461347, 3461370, 3461371, 3461372, 3401981, 3461377, 3402002, 3402003, 3465516, 3465525, 3469663, 3469670, 3469671, 3418481, 3418482, 3422605, 3410319, 3422635, 3422636, 3422638, 3426782, 3426783, 3426784, 3430888, 3430889, 3426807, 3430915, 3430916, 3430917, 3430918, 3430919, 3430920, 3430921, 3430922, 3430923, 3430924, 3430925, 3430926, 3422735, 3430927, 3430928, 3422738, 3430930, 3430929, 3430933, 3430934, 3430935, 3430936, 3430937, 3436473, 3430941, 3430942, 3430943, 3430944, 3430945, 3430946, 3430947, 3430948, 3430949, 3430953, 3430954, 3430959, 3430962, 3430966, 3439182, 3439183, 3439184, 3439185, 3439186, 3439187, 3435092, 3435093, 3435094, 3435095, 3435090, 3435097, 3435098, 3435099, 3435100, 3435101, 3435102, 3439196, 3439194, 3435096, 3431015, 3439208, 3435113, 3439209, 3439211, 3439212, 3439213, 3439214, 3431023, 3431024, 3431025, 3431022, 3431027, 3431020, 3439223, 3439224, 3439225, 3439226, 3439227, 3439229, 3439230, 3439231, 3439232, 3439233, 3439234, 3439235, 3443332, 3443333, 3443334, 3439239, 3439240, 3439241, 3439242, 3439243, 3439247, 3439252, 3439253, 3439258, 3435163, 3435164, 3435165, 3435166, 3439259, 3439264, 3439263, 3439266, 3439262, 3439261, 3439260, 3439271, 3435176, 3435175, 3435178, 3435179, 3435185, 3443378, 3439348, 3440589, 3440590, 3440592, 3440593, 3455784, 3459958, 3396473, 3396476, 3400599, 3459996, 3459997, 3459998, 3459999, 3460000, 3460001, 3460002, 3460003, 3464105, 3400620, 3400621, 3400622, 3464134, 3464135, 3468280, 3468289, 3468295, 3417098, 3417099, 3417100, 3417101, 3429655, 3429656, 3429657, 3472427, 3429658, 3429659, 3429660, 3421242, 3429661, 3421254, 3413074, 3476569, 3476575, 3476576, 3425401, 3425402, 3425403, 3429546, 3429547, 3429563, 3429568, 3437799, 3437800, 3437801, 3437802, 3437804, 3437826, 3429638, 3437841, 3437842, 3437843, 3437844, 3437845, 3437847, 3437848, 3437849, 3437850, 3441947, 3441948, 3437851, 3437852, 3441951, 3441952, 3437856, 3437858, 3437859, 3437860, 3437857, 3437855, 3437854, 3437865, 3437869, 3437870, 3437876, 3437877, 3437878, 3437880, 3437881, 3437853, 3437882, 3433788, 3442035, 3442036, 3437949, 3390851, 3446182, 3446183, 3399234, 3462723, 3399239, 3399240, 3462761, 3471044, 3471054, 3431016, 3431017, 3431018, 3435089, 3431019, 3411696, 3435091, 3411701, 3475196, 3424017, 3424018, 3424019, 3428164, 3428166, 3428180, 3428181, 3428185, 3432309, 3432310, 3432312, 3432324, 3436420, 3436460, 3436461, 3436462, 3436463, 3436466, 3436467, 3436468, 3440565, 3440566, 3436471, 3436472, 3440567, 3436474, 3440568, 3436470, 3436469, 3436475, 3436476, 3436478, 3436479, 3436477, 3436481, 3436480, 3436484, 3436483, 3436487, 3440584, 3436482, 3440586, 3436491, 3440588, 3440587, 3440585, 3436495, 3436496, 3436497, 3440594, 3440595, 3440596, 3440597, 3440598, 3440599, 3436498, 3436500, 3436501, 3440601, 3440602, 3440603, 3440606, 3440607, 3440600, 3440605, 3440609, 3440611, 3440612, 3440608, 3440614, 3440615, 3440616, 3444716, 3440621, 3440622, 3440623, 3440624, 3440625, 3440626, 3440627, 3440628, 3440635, 3440639]
rg = 9
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-37-6577a325f305>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-37-6577a325f305>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-37-6577a325f305>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 9

# %%
os = [3139593, 3139599, 3139600, 3139607, 3258401, 3258403, 3199014, 3199015, 3199021, 3199022, 3203163, 3203164, 3203165, 3147886, 3207301, 3207305, 3207306, 3207307, 3207308, 3207315, 3207316, 3207317, 3207318, 3211447, 3211448, 3211458, 3211459, 3211460, 3211462, 3156177, 3215595, 3215604, 3215613, 3215614, 3219730, 3219748, 3219752, 3219753, 3219754, 3223886, 3223887, 3223888, 3223889, 3223890, 3223891, 3223892, 3223893, 3223894, 3223896, 3223897, 3223898, 3223899, 3223903, 3223904, 3223905, 3223909, 3228017, 3228018, 3228038, 3228039, 3228040, 3228041, 3228042, 3228043, 3228044, 3228045, 3228046, 3228047, 3228048, 3228050, 3228051, 3228052, 3232160, 3232185, 3232187, 3232189, 3232190, 3232192, 3232193, 3232194, 3232198, 3236313, 3236314, 3236331, 3236332, 3236333, 3236334, 3236336, 3236339, 3236340, 3236345, 3236348, 3240481, 3240483, 3134070, 3134071, 3134072, 3134073, 3134074, 3134075, 3134076, 3252867, 3252873, 3252875, 3134098, 3252896, 3138216, 3138217, 3138218, 3138219, 3257018, 3197633, 3197634, 3197635, 3197636, 3197637, 3197639, 3257040, 3142353, 3142354, 3142369, 3261167, 3261168, 3201779, 3257078, 3201784, 3201785, 3205919, 3205926, 3205927, 3205931, 3205932, 3261229, 3205933, 3205934, 3210078, 3210079, 3269472, 3269473, 3269474, 3269476, 3210084, 3269480, 3269481, 3269482, 3269483, 3269488, 3214213, 3214214, 3214215, 3214216, 3214217, 3214218, 3214225, 3214227, 3218348, 3218357, 3273653, 3273654, 3218361, 3218369, 3218371, 3218372, 3218373, 3218376, 3222504, 3277801, 3222505, 3222506, 3222507, 3222508, 3222509, 3222510, 3222511, 3222512, 3222514, 3222515, 3222516, 3222517, 3222518, 3226636, 3226643, 3226650, 3226651, 3226653, 3226656, 3226657, 3226658, 3226660, 3226661, 3226662, 3226663, 3226664, 3226665, 3226666, 3226669, 3230782, 3230783, 3230803, 3230806, 3230807, 3230808, 3230809, 3230810, 3230811, 3234931, 3234951, 3234952, 3234953, 3234954, 3234955, 3234959, 3234964, 3239079, 3239098, 3239100, 3239109, 3239110, 3243221, 3247346, 3132691, 3132692, 3132693, 3132694, 3132695, 3132696, 3132697, 3247394, 3251492, 3251493, 3136835, 3136836, 3136837, 3136838, 3136839, 3136840, 3255633, 3255637, 3196253, 3196254, 3196258, 3196259, 3140987, 3259785, 3259786, 3200394, 3200395, 3200403, 3200404, 3204541, 3204542, 3204543, 3204544, 3204548, 3149268, 3208692, 3208696, 3208698, 3268091, 3268092, 3208699, 3212832, 3212833, 3212842, 3212843, 3212846, 3212847, 3216964, 3221105, 3221106, 3221122, 3221123, 3221125, 3221126, 3221127, 3221128, 3221129, 3221130, 3221136, 3225252, 3225253, 3225268, 3225269, 3225270, 3225271, 3225272, 3225273, 3225274, 3225275, 3225277, 3225279, 3225280, 3225281, 3225283, 3225289, 3225290, 3229400, 3229421, 3229424, 3229425, 3229426, 3229427, 3229429, 3229430, 3229440, 3233548, 3233568, 3233569, 3233570, 3233571, 3233574, 3233575, 3233585, 3237698, 3237717, 3237718, 3237729, 3241863, 3250134, 3135454, 3135455, 3135456, 3254241, 3135457, 3135458, 3135460, 3135461, 3135459, 3254254, 3254255, 3254256, 3254258, 3194870, 3194871, 3194874]
rg = 10
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-37-6577a325f305>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-37-6577a325f305>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-37-6577a325f305>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 10

# %%
os = [3368992, 3368993, 3368994, 3432530, 3432531, 3432532, 3432533, 3432534, 3432535, 3373141, 3432537, 3432538, 3432539, 3432540, 3432541, 3432542, 3432543, 3432544, 3432551, 3432552, 3432553, 3432554, 3432555, 3432557, 3432559, 3432561, 3436679, 3436680, 3436681, 3436682, 3436683, 3436684, 3436685, 3436686, 3436687, 3377294, 3436699, 3436700, 3436701, 3436702, 3436703, 3436704, 3436705, 3436706, 3436707, 3436708, 3385506, 3440822, 3440823, 3440825, 3440826, 3381442, 3381443, 3444942, 3440847, 3440849, 3389655, 3389656, 3440857, 3444971, 3385589, 3444982, 3444981, 3444987, 3444989, 3393799, 3393801, 3445005, 3445006, 3445007, 3449120, 3449122, 3449124, 3389735, 3449127, 3389738, 3449136, 3449137, 3449138, 3445044, 3449141, 3449146, 3449152, 3393865, 3393866, 3393874, 3393880, 3449177, 3393884, 3453277, 3453287, 3453288, 3397997, 3398011, 3453315, 3453316, 3398021, 3453319, 3453322, 3398027, 3453323, 3457434, 3457435, 3457437, 3457438, 3402158, 3402159, 3402160, 3402161, 3406262, 3457466, 3457467, 3402171, 3457469, 3402172, 3457470, 3457472, 3457473, 3402178, 3457471, 3461585, 3461586, 3461587, 3461591, 3410402, 3410403, 3410404, 3410405, 3406307, 3406306, 3410412, 3406317, 3406318, 3465732, 3465733, 3465734, 3465736, 3465737, 3465738, 3465739, 3410447, 3410448, 3410451, 3410453, 3410454, 3410455, 3414552, 3414553, 3414554, 3410456, 3465753, 3414551, 3410463, 3410464, 3355173, 3355176, 3414577, 3414578, 3414579, 3469882, 3469883, 3469904, 3359318, 3359319, 3359320, 3359321, 3363456, 3363458, 3363462, 3363463, 3363464, 3367605, 3367606, 3367609, 3367610, 3367611, 3367612, 3371758, 3371759, 3431169, 3431173, 3431174, 3431177, 3435296, 3435297, 3435298, 3435299, 3435300, 3435301, 3435302, 3435303, 3435304, 3435305, 3435316, 3435317, 3435318, 3435319, 3435320, 3435321, 3435322, 3435325, 3435326, 3439443, 3439444, 3439447, 3439448, 3439449, 3439450, 3439451, 3380064, 3439463, 3439464, 3439468, 3439469, 3439470, 3439471, 3443586, 3443587, 3443588, 3443589, 3443598, 3384207, 3443599, 3443600, 3384210, 3384211, 3384208, 3384206, 3447711, 3392418, 3392419, 3443621, 3443625, 3447721, 3447724, 3447728, 3447730, 3447731, 3447732, 3388341, 3447733, 3447738, 3447739, 3447740, 3388349, 3447741, 3447742, 3388352, 3388353, 3388356, 3447752, 3447753, 3447754, 3392484, 3392491, 3392496, 3451894, 3392503, 3451905, 3396629, 3396630, 3451931, 3396649, 3396651, 3456052, 3400776, 3400777, 3400778, 3400779, 3400780, 3456085, 3400790, 3456086, 3460208, 3404923, 3404924, 3409021, 3404925, 3409027, 3404933, 3404935, 3404936, 3409031, 3460232, 3464350, 3464351, 3464355, 3464356, 3464357, 3464358, 3409070, 3409071, 3409072, 3409073, 3413166, 3353777, 3353781, 3413174, 3353782, 3413176, 3409081, 3409082, 3409083, 3468499, 3468500, 3468501, 3357913, 3357914, 3357922, 3468520, 3468521, 3413230, 3357935, 3357936, 3357937, 3362080, 3362081, 3362082, 3362083, 3362084, 3362085, 3366222, 3366224, 3366226, 3366227, 3366228, 3366230, 3373140, 3370373, 3370375, 3370376, 3433914, 3433915, 3433916, 3433917, 3433919, 3433920, 3433921, 3433922, 3433923, 3433924, 3374527, 3433927, 3433928, 3433934, 3433935, 3433940, 3433943, 3438061, 3438062, 3438064, 3438065, 3438066, 3438067, 3438068, 3438069, 3378674, 3438074, 3438081, 3438082, 3438085, 3438086, 3438087, 3438088, 3386889, 3442207, 3442208, 3442209, 3442215, 3442222, 3391036, 3391037, 3446350, 3386959, 3446351, 3446352, 3446356, 3446357, 3446358, 3442264, 3386971, 3446364, 3446365, 3386974, 3446366, 3446367, 3446369, 3446372, 3446374, 3446382, 3446386, 3446387, 3446388, 3450485, 3391101, 3450502, 3391116, 3391117, 3450511, 3450512, 3450513, 3446416, 3446417, 3450520, 3450522, 3450527, 3395233, 3395263, 3450560, 3450559, 3395267, 3454669, 3399394, 3399395, 3399396, 3399397, 3454698, 3399404, 3399408, 3454707, 3454708, 3454709, 3458815, 3458817, 3458818, 3458819, 3458820, 3458823, 3458833, 3403542, 3403544, 3407642, 3407644, 3407645, 3403552, 3403553, 3403554, 3458848, 3458849, 3458850, 3458851, 3462967, 3462968, 3462969, 3407688, 3407689, 3407690, 3411787, 3411788, 3411786, 3411785, 3411784, 3411795, 3407700, 3407699, 3352412, 3352413, 3352414, 3467116, 3467117, 3467118, 3467119, 3467120, 3411834, 3411838, 3467140, 3467142, 3411847, 3411848, 3356554, 3356555, 3356556, 3467151, 3360699, 3360701, 3360702, 3360703, 3364844, 3364845, 3364846, 3364847]
rg = 11
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-37-6577a325f305>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-37-6577a325f305>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-37-6577a325f305>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 11

# %%
os = [3548741, 3547282, 3547283, 3547284, 3547285, 3547286, 3547287, 3547288, 3547289, 3547290, 3547291, 3548743, 3547295, 3547296, 3547297, 3547298, 3547299, 3547300, 3547301, 3548745, 3548747, 3547308, 3547310, 3548748, 3547317, 3547318, 3547319, 3551427, 3551428, 3551429, 3551430, 3551431, 3551432, 3551433, 3551434, 3551435, 3551436, 3547343, 3551440, 3547346, 3548755, 3551445, 3548756, 3551449, 3551450, 3551452, 3551453, 3551454, 3551455, 3551456, 3551458, 3551459, 3547363, 3551461, 3551462, 3551463, 3547367, 3551465, 3548759, 3551467, 3547372, 3551469, 3551470, 3551471, 3551472, 3551473, 3551474, 3547379, 3551475, 3551476, 3547375, 3547374, 3555575, 3551480, 3551481, 3551482, 3555579, 3555578, 3555581, 3555577, 3555576, 3551488, 3555580, 3555582, 3555583, 3555588, 3555589, 3555590, 3555591, 3555587, 3555586, 3548765, 3555597, 3555598, 3555599, 3548767, 3551506, 3551507, 3551508, 3555607, 3555608, 3555609, 3555610, 3555611, 3555613, 3555614, 3551523, 3551524, 3551525, 3551526, 3551527, 3551528, 3551529, 3551530, 3551531, 3551532, 3551533, 3551534, 3555631, 3551536, 3555637, 3555656, 3555657, 3555671, 3555672, 3555679, 3568011, 3568025, 3568037, 3568038, 3568039, 3568042, 3568054, 3568061, 3568062, 3568067, 3568068, 3568069, 3568070, 3568071, 3568073, 3572175, 3572178, 3572179, 3572180, 3572181, 3572182, 3572183, 3572184, 3572185, 3572186, 3572188, 3572189, 3572193, 3572194, 3572203, 3572210, 3572223, 3576324, 3576325, 3576326, 3548760, 3550046, 3548761, 3550048, 3548762, 3548763, 3548764, 3550084, 3550093, 3550094, 3545898, 3545899, 3545901, 3545902, 3545904, 3545905, 3545906, 3545907, 3545908, 3550097, 3550098, 3545912, 3545913, 3545914, 3545915, 3550099, 3550100, 3545922, 3545931, 3545933, 3545934, 3545935, 3545936, 3545937, 3545950, 3550047, 3545952, 3545953, 3550050, 3550051, 3545956, 3545957, 3545958, 3545959, 3545960, 3550052, 3550049, 3550061, 3550062, 3550067, 3550068, 3550069, 3550071, 3550073, 3550074, 3550075, 3550076, 3550078, 3550079, 3550080, 3545985, 3545986, 3550082, 3545988, 3550085, 3550086, 3550087, 3550088, 3550089, 3550090, 3550091, 3545996, 3550092, 3545998, 3550095, 3550096, 3546001, 3554193, 3554194, 3554195, 3554196, 3554197, 3554198, 3554199, 3554200, 3554201, 3554202, 3546007, 3550102, 3550101, 3554214, 3554216, 3554217, 3550123, 3550125, 3550126, 3550127, 3554225, 3554226, 3554227, 3554228, 3550132, 3550134, 3550131, 3554236, 3550141, 3554238, 3554239, 3554240, 3554241, 3550146, 3558339, 3558340, 3550149, 3558342, 3558343, 3558344, 3558345, 3558346, 3558347, 3558348, 3558349, 3558350, 3558351, 3558352, 3554252, 3558363, 3558365, 3558366, 3558367, 3554272, 3558369, 3554273, 3558373, 3558374, 3554295, 3554297, 3554298, 3554303, 3554304, 3554305, 3550142, 3550143, 3550144, 3550145, 3550147, 3550148, 3550150, 3550151, 3550152, 3566680, 3566681, 3566682, 3566684, 3566685, 3566687, 3566688, 3566689, 3566690, 3566691, 3566694, 3570801, 3570802, 3570806, 3570812, 3570817, 3570818, 3570827, 3570841, 3570842, 3574943, 3574944, 3574945, 3574950, 3574951, 3574952, 3574953, 3574954, 3574967, 3574972, 3574987, 3547371, 3547373, 3547376, 3547377, 3547378, 3547380, 3547381, 3547382, 3548663, 3548665, 3548666, 3548667, 3548668, 3548669, 3548670, 3548671, 3548672, 3544577, 3544578, 3544579, 3481092, 3548677, 3548678, 3548679, 3548680, 3548681, 3548682, 3544580, 3548687, 3548689, 3548690, 3548691, 3548692, 3548693, 3548696, 3548701, 3548702, 3548703, 3544612, 3548711, 3544616, 3548713, 3552812, 3552813, 3552814, 3552815, 3552816, 3552817, 3552818, 3552819, 3552820, 3552821, 3548718, 3548730, 3552829, 3552832, 3552833, 3552834, 3552835, 3552836, 3552837, 3552838, 3552839, 3548744, 3552841, 3548746, 3552843, 3552844, 3548749, 3552846, 3548751, 3548752, 3548753, 3548750, 3552851, 3552852, 3552853, 3552854, 3552855, 3552856, 3552857, 3552858, 3552859, 3548758, 3556957, 3548757, 3552863, 3556960, 3556961, 3556959, 3548768, 3556964, 3556965, 3556966, 3556967, 3556968, 3556969, 3556970, 3556971, 3556972, 3556973, 3556974, 3556980, 3552890, 3552891, 3556988, 3556989, 3556991, 3556992, 3556995, 3556998, 3552908, 3552909, 3552910, 3552911, 3552912, 3552914, 3552915, 3552916, 3557011, 3557012, 3557013, 3557014, 3557017, 3557018, 3557016, 3557015, 3544575, 3557036, 3555584, 3555585, 3573560, 3573561, 3573562, 3573563, 3573564, 3573565, 3573567, 3573568, 3573569, 3573570, 3573571, 3573575, 3573576, 3573580, 3573605]
rg = 12
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-37-6577a325f305>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-37-6577a325f305>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-37-6577a325f305>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 12

# %%
os = [3416092, 3364904, 3364905, 3420228, 3420231, 3364946, 3364947, 3364948, 3364953, 3364954, 3364979, 3364981, 3424374, 3424375, 3424376, 3424377, 3364984, 3364985, 3364982, 3364983, 3369096, 3369097, 3369098, 3373200, 3369106, 3369107, 3369109, 3369113, 3428507, 3428508, 3428509, 3428510, 3424415, 3369123, 3369125, 3369126, 3369128, 3377321, 3428522, 3428523, 3428524, 3369130, 3369132, 3428528, 3428529, 3373236, 3373248, 3373249, 3373250, 3432649, 3373261, 3432654, 3432655, 3432656, 3432657, 3373267, 3373270, 3373272, 3373273, 3373274, 3373275, 3373276, 3432669, 3432670, 3432671, 3373277, 3436772, 3436773, 3436779, 3432684, 3432685, 3377389, 3377397, 3436795, 3436796, 3436798, 3377407, 3377408, 3436799, 3440901, 3377416, 3377417, 3377418, 3440904, 3377420, 3377421, 3377422, 3377423, 3436819, 3436820, 3440920, 3440921, 3381541, 3440937, 3440942, 3381553, 3381557, 3381558, 3381559, 3381560, 3445049, 3381565, 3381566, 3381567, 3381568, 3381569, 3445059, 3445062, 3445063, 3440974, 3389784, 3445081, 3385690, 3445087, 3385707, 3385708, 3385709, 3385710, 3449200, 3385713, 3385714, 3385715, 3449204, 3449205, 3385721, 3393928, 3445141, 3389857, 3389858, 3389859, 3389861, 3389862, 3389863, 3389864, 3389865, 3389866, 3393987, 3398130, 3398136, 3398137, 3398165, 3402271, 3402311, 3461740, 3406458, 3410567, 3367658, 3363563, 3367659, 3363565, 3363566, 3363568, 3363570, 3367667, 3367668, 3367669, 3363576, 3363581, 3422983, 3363597, 3363598, 3363599, 3363600, 3363601, 3363602, 3363604, 3367714, 3367715, 3367718, 3367723, 3427123, 3367742, 3375939, 3367748, 3427141, 3427142, 3375944, 3427145, 3371863, 3371864, 3371865, 3371866, 3371874, 3431271, 3431272, 3431273, 3431274, 3431276, 3371888, 3371889, 3371890, 3371891, 3431284, 3371893, 3371894, 3431287, 3431288, 3431289, 3431290, 3431286, 3431285, 3431293, 3371895, 3371896, 3371898, 3435396, 3376005, 3431303, 3431304, 3435412, 3435414, 3435417, 3376035, 3376036, 3376037, 3376038, 3376039, 3376040, 3376041, 3435436, 3435437, 3376045, 3376046, 3439536, 3380152, 3384249, 3380157, 3384255, 3380170, 3380174, 3380175, 3380176, 3443667, 3380183, 3380184, 3380185, 3380186, 3384283, 3443682, 3443683, 3443684, 3439591, 3384307, 3443700, 3443702, 3443703, 3443706, 3384325, 3384326, 3384327, 3384330, 3384331, 3384332, 3384333, 3388429, 3447823, 3384337, 3384338, 3384339, 3443738, 3443739, 3443758, 3388473, 3388474, 3388475, 3388476, 3388479, 3388483, 3388484, 3388485, 3388486, 3392598, 3392622, 3392623, 3392624, 3392625, 3396746, 3396747, 3396753, 3396778, 3400894, 3409134, 3409138, 3405069, 3464504, 3409216, 3409217, 3409222, 3409223, 3409224, 3413352, 3417471, 3366283, 3366286, 3370414, 3366329, 3366330, 3366331, 3366332, 3366334, 3366335, 3370434, 3366346, 3366349, 3366359, 3425756, 3425757, 3425758, 3425759, 3366365, 3425761, 3366366, 3366369, 3374566, 3374567, 3425775, 3370480, 3370481, 3370482, 3370483, 3481076, 3370479, 3370484, 3370507, 3370508, 3429902, 3429903, 3370512, 3429905, 3429906, 3429904, 3370510, 3429909, 3429910, 3370511, 3370518, 3370516, 3374618, 3374619, 3434036, 3374651, 3374652, 3374653, 3374654, 3374655, 3374656, 3374661, 3374662, 3434054, 3434053, 3434067, 3378772, 3378773, 3378774, 3438174, 3438179, 3438180, 3378791, 3378800, 3378801, 3378802, 3378803, 3378804, 3378805, 3378806, 3438201, 3442299, 3442301, 3442302, 3438209, 3438210, 3387014, 3382923, 3442320, 3442322, 3387027, 3382941, 3382942, 3382946, 3382947, 3382948, 3382949, 3382950, 3446439, 3382952, 3382953, 3382951, 3442357, 3387073, 3442376, 3442377, 3387092, 3387093, 3450582, 3450583, 3450584, 3387097, 3387101, 3387102, 3387103, 3387104, 3450590, 3450591, 3450592, 3391221, 3391222, 3391239, 3391240, 3391241, 3391242, 3391244, 3391245, 3391246, 3391247, 3391248, 3391249, 3391250, 3391251, 3395371, 3399512, 3399515, 3399519, 3399520, 3399546, 3399547, 3407755, 3403693, 3463107, 3463121, 3407839, 3411949, 3411951, 3416059]
rg = 13
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-37-6577a325f305>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-37-6577a325f305>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-37-6577a325f305>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Region 13

# %%
os = [3457393]
rg = 17
x = f"{data_dir}/preliminary site selection/RG{rg}/rg{rg}_clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-37-6577a325f305>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-37-6577a325f305>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-37-6577a325f305>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # BARMM

# %%
os = [3338631, 3338632, 2990473, 2983563, 3117580, 3326222, 3117583, 2978064, 3326224, 3326225, 3326226, 3345552, 3337238, 3337252, 3335842, 3335843, 2996004, 3335844, 3337250, 3337251, 3324840, 3116201, 2976682, 3109290, 3322028, 3324841, 3324842, 3328938, 3121717, 2708537, 2994618, 3349692, 3349693, 3121727, 2982208, 3327553, 3327554, 3330370, 3113425, 2860628, 2860629, 3333079, 3348311, 3348312, 3348313, 3113435, 3322076, 3328988, 3348316, 2984943, 2984944, 2991856, 3331699, 3112052, 3112053, 3112054, 3327604, 2972536, 3327605, 3331700]
rg = 'barmm'
x = f"{data_dir}/preliminary site selection/BARMM/barmm-clusters.csv"
rg1_clustered_df = pd.read_csv(x)
rg1_clustered_df

''' OR PREP '''
os_df = process_population_density(rg1_clustered_df, os)
os_df['HCFAI'] = HCI_calc(os_df['popden_all'], os_df['popden_chi'], os_df['popden_eld'],
                          os_df['popden_wom'],  os_df['popden_you'],  os_df['popden_w_1'],
                          os_df['Distance_to_Nearest_RHU_km'], os_df['Road_Presence'],
                          os_df['POI_Presence'], os_df['buildability_landcov'],
                          os_df['rain intensity_value'],
                          os_df['flood_probability_value'],
                          os_df['drought_value'], os_df['RHU_Presence'])

print(os_df['city_name'].unique())
grouped_df = os_df.groupby('city_name')
print(grouped_df)
# Convert each group back into a DataFrame and concatenate them into a single DataFrame
grouped_df_visual = grouped_df.apply(lambda x: x.reset_index(drop=True))
grouped_df_visual
total_population_by_city = grouped_df_visual[['total_population', 'popden_all']]
total_population_by_city_df = total_population_by_city.reset_index()
total_population_by_city_df
# Group the DataFrame total_population_by_city_df by 'city_name' and calculate the sum of 'total_population'
total_population_grouped = total_population_by_city_df.groupby('city_name').sum()
# Reset the index to make 'city_name' a regular column again
total_population_grouped = total_population_grouped.reset_index()
# Now you can print or display the DataFrame
# total_population_grouped = total_population_grouped.drop(columns=['level_1'])
total_population_grouped
# Convert the DataFrame total_population_grouped into a dictionary
total_population_dict = total_population_grouped.set_index('city_name')['total_population'].to_dict()
# Now you can print or display the dictionary
#print(total_population_dict)
total_population_dict
print(total_population_dict)

''' OR '''
rhu_capacity = 20000
# Dictionary to store solutions for each solver
all_solutions = {}
solver_names = ['SAT', 'SCIP', 'GLOP', 'CBC']
# Iterate over each solver
for solver_name in solver_names:
    print(f"Solving with {solver_name} solver...")
    # Create the solver instance
    if solver_name == 'SAT':
        solver = pywraplp.Solver.CreateSolver('SAT')
    elif solver_name == 'SCIP':
        solver = pywraplp.Solver.CreateSolver('SCIP')
    elif solver_name == 'GLOP':
        solver = pywraplp.Solver.CreateSolver('GLOP')
    elif solver_name == 'CBC':
        solver = pywraplp.Solver.CreateSolver('CBC')
    else:
        raise ValueError(f"Unknown solver: {solver_name}")
    if not solver:
        raise Exception(f"{solver_name} solver not found!")

    # Define decision variables (number of RHUs to build for each city)
    rhus = {city: solver.IntVar(0, solver.infinity(), f'rhus_{city}') for city in total_population_dict.keys()}

    # Constraint: Ensure that the number of RHUs built in each city does not exceed the total population divided by the RHU capacity
    for city, population in total_population_dict.items():
        solver.Add(rhus[city] * rhu_capacity <= population)

    # Define the objective function: Maximize the total number of RHUs
    objective = solver.Objective()
    for city in rhus:
        objective.SetCoefficient(rhus[city], 1)
    objective.SetMaximization()

    # Solve the problem
    status = solver.Solve()

    # Check the result
    if status in [pywraplp.Solver.OPTIMAL]:
        print(f'Optimal solution found with {solver_name}!')
        total_rhus = 0
        rhus_per_city = {}
        for city in rhus:
            num_rhus = int(rhus[city].solution_value())
            total_rhus += num_rhus
            rhus_per_city[city] = num_rhus
            if num_rhus > 0:
                print(f'{city}: Build {num_rhus} RHUs')
        print(f'Total RHUs built: {total_rhus}')
        all_solutions[solver_name] = rhus_per_city
    else:
        print(f'No optimal solution found with {solver_name}.')

# Assuming 'os_df' is your DataFrame containing city information
# Create a new column 'num_rhus' in os_df based on the solutions from all solvers
for solver_name, rhus_per_city in all_solutions.items():
    os_df[f'num_rhus_{solver_name}'] = os_df['city_name'].map(rhus_per_city).fillna(0).astype(int)


''' RECOMMENDER '''
# Load the filtered dataset
cities_in_solution = rhus_per_city.keys()
filtered_df = os_df[os_df['city_name'].isin(cities_in_solution)]

# Calculate priority score for each location in the new dataset
filtered_df['Priority_Score'] = 0
for group, weight in weights.items():
    filtered_df['Priority_Score'] += filtered_df[group] * weight

# Load the saved scaler
scaler = joblib.load(f'{data_dir}/[prioritize]/scaler.pkl')

# Normalize features using the same scaler fitted on PCF_df
X_new = scaler.transform(filtered_df[['popden_wom', 'popden_chi', 'popden_w_1', 'popden_you', 'popden_eld', 'popden_all']])

# Load the trained models and make predictions on the new dataset
for name in ['Decision_Tree', 'SVR', 'Random_Forest', 'KNN', 'Neural_Network']:
    model = joblib.load(f'{data_dir}/[prioritize]/{name}_model.pkl')
    preds = model.predict(X_new)
    filtered_df[f'{name}_Prediction'] = preds

print(filtered_df[['ID', 'Priority_Score', 'Decision_Tree_Prediction', 'SVR_Prediction', 'Random_Forest_Prediction', 'KNN_Prediction', 'Neural_Network_Prediction']])

# Recommend top N locations per city
recommended_locations = {name: {} for name in models.keys()}

for name in models.keys():
  for city, num_rhus in rhus_per_city.items():
      city_locations = filtered_df[filtered_df['city_name'] == city]
      top_locations = city_locations.nlargest(num_rhus, f'{name.replace(" ", "_")}_Prediction')
      # Store recommended locations in a list
      recommended_locations[name][city] = top_locations['ID'].tolist()

all_locations = []
for name in models.keys():
  model_locations = []
  print(f"Model: {name}")
  for city, locations in recommended_locations[name].items():
    if locations != []:
      print(f"Recommended locations for {city}: {locations}")
      model_locations.append(locations)
  all_locations.append(model_locations)
# Out:
# <ipython-input-37-6577a325f305>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population'] = all_pd * a
# <ipython-input-37-6577a325f305>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   os_df['total_population_women'] = women_pd * a
# <ipython-input-37-6577a325f305>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # CAR
